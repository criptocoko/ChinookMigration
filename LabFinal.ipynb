# %% [markdown]
# # Migración Base de Datos Chinook: PostgreSQL → MongoDB
#
# Este notebook implementa la migración completa de la base de datos relacional Chinook desde PostgreSQL hacia MongoDB, como parte del laboratorio final del curso de Bases de Datos No Relacionales.
#
# ## Objetivos del Proyecto
#
# 1. **Migración de esquema**: Transformar el modelo relacional en documentos MongoDB optimizados
# 2. **Comparación de consultas**: Demostrar diferencias entre SQL y agregaciones MongoDB
# 3. **Optimización**: Implementar índices y campos calculados para mejor rendimiento
# 4. **Análisis**: Documentar ventajas y desventajas de cada enfoque
#
# ## Base de Datos Original
# - **Fuente**: [Chinook Database](https://github.com/lerocha/chinook-database)
# - **Dominio**: Tienda de música digital (iTunes-like)
# - **Estructura**: 11 tablas relacionales normalizadas
#
# ## Estrategia de Migración
# - **Albums**: Embeber tracks dentro de álbumes
# - **Customers**: Embeber facturas completas con líneas
# - **Employees**: Embeber clientes asignados
# - **Tracks**: Agregar estadísticas de ventas precalculadas
# - **Playlists**: Mantener referencias a tracks
#
# ---

# %%
pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.11/dist-packages (2.9.10)

# %%
# !pip install pymongo[srv] pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Collecting pymongo[srv]
#   Downloading pymongo-4.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# WARNING: pymongo 4.13.1 does not provide the extra 'srv'
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 5.5 MB/s eta 0:00:00
# Downloading pymongo-4.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 31.4 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.13.1

# %%
#Connect db
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd
from bson import ObjectId
import datetime
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Connect to MongoDB using environment variables
mongodb_password = os.getenv('MONGODB_PASSWORD')
mongodb_username = os.getenv('MONGODB_USERNAME')
mongodb_cluster = os.getenv('MONGODB_CLUSTER')

if not all([mongodb_password, mongodb_username, mongodb_cluster]):
    raise ValueError("Missing MongoDB environment variables. Please check your .env file.")

uri = f"mongodb+srv://{mongodb_username}:{mongodb_password}@{mongodb_cluster}/?retryWrites=true&w=majority&appName=Cluster0"

client = MongoClient(uri, server_api=ServerApi('1'))

try:
    client.admin.command('ping')
    print("✅ Connected to MongoDB!")
except Exception as e:
    print("❌ Connection failed:", e)
# Out:
# ✅ Connected to MongoDB!

# %%
db= client['chinook-music-store']

# %%
# Helper function for PostgreSQL connections
def get_postgres_connection():
    """Get PostgreSQL connection using environment variables"""
    postgres_username = os.getenv('POSTGRES_USERNAME')
    postgres_password = os.getenv('POSTGRES_PASSWORD')
    postgres_host = os.getenv('POSTGRES_HOST')
    postgres_database = os.getenv('POSTGRES_DATABASE')
    
    if not all([postgres_username, postgres_password, postgres_host, postgres_database]):
        raise ValueError("Missing PostgreSQL environment variables. Please check your .env file.")
    
    connection_string = f"postgresql://{postgres_username}:{postgres_password}@{postgres_host}/{postgres_database}"
    return psycopg2.connect(connection_string)

# %%
import psycopg2
# Mostrar playlist donde aparezca una cancion con cierto id # Resultado da igual
# Conexión usando variables de entorno
conn = get_postgres_connection()

cur = conn.cursor()

# Ejecutar una consulta
cur.execute("""
    SELECT name from playlist p
    LEFT JOIN playlist_track pt on pt.playlist_id = p.playlist_id
    where pt.track_id = 3
""")
rows = cur.fetchall()

# Mostrar resultados
for row in rows:
    print(row)



# Cerrar conexiones
cur.close()
conn.close()

print("------------------------------")

results = db.playlists.find({
    'tracks.track_id': 4
})

for playlist in results:
  print(playlist['name'])
# Out:
# ('Music',)
# ('90’s Music',)
# ('Music',)
# ('Heavy Metal Classic',)
# ------------------------------
# Music
# 90’s Music
# Music
# Heavy Metal Classic

# %%
import psycopg2
# Mostrar los clientes que atendio un empleado con cierto id # Resultado da igual
# Conexión usando el URI completo
conn = psycopg2.connect("postgresql://lab2user:n4yyQSda08pJT8ucHDe9Y7SSGskYzldJ@dpg-d0r462idbo4c73a0sqs0-a.virginia-postgres.render.com/chinook")

cur = conn.cursor()

# Ejecutar una consulta
cur.execute("""
    SELECT first_name FROM customer c
    where c.support_rep_id = 4
""")
rows = cur.fetchall()

# Mostrar resultados
for row in rows:
    print(row)



# Cerrar conexiones
cur.close()
conn.close()

print("------------------------------")

employee_id = 4



cursor = db.employees.find(
    {'employee_id': employee_id},
    {'customers.customer_name': 1, '_id': 0}
)

for doc in cursor:
    for customer in doc.get('customers', []):
        print(customer['customer_name'])
# Out:
# ('Bjørn',)
# ('František',)
# ('Daan',)
# ('Kara',)
# ('Eduardo',)
# ('Fernanda',)
# ('Frank',)
# ('Dan',)
# ('Heather',)
# ('John',)
# ('Richard',)
# ('Patrick',)
# ('Aaron',)
# ('João',)
# ('Madalena',)
# ('Camille',)
# ('Dominique',)
# ('Stanisław',)
# ('Mark',)
# ('Diego',)
# ------------------------------
# Bjørn Hansen
# František Wichterlová
# Daan Peeters
# Kara Nielsen
# Eduardo Martins
# Fernanda Ramos
# Frank Harris
# Dan Miller
# Heather Leacock
# John Gordon
# Richard Cunningham
# Patrick Gray
# Aaron Mitchell
# João Fernandes
# Madalena Sampaio
# Camille Bernard
# Dominique Lefebvre
# Stanisław Wójcik
# Mark Taylor
# Diego Gutiérrez

# %%
import psycopg2
import os
# Mostrar los clientes ordenados por quien gasto mas en canciones # Resultado igual
# Conexión usando variables de entorno
conn = get_postgres_connection()

cur = conn.cursor()

# Ejecutar una consulta
cur.execute("""
    SELECT c.customer_id, c.first_name, c.last_name, SUM(inl.unit_price * inl.quantity) as total FROM customer c
    LEFT JOIN invoice inv on inv.customer_id = c.customer_id
    LEFT JOIN invoice_line inl on inv.invoice_id = inl.invoice_id
    GROUP BY c.customer_id, c.first_name, c.last_name
    ORDER BY total desc

""")
rows = cur.fetchall()

# Mostrar resultados
for row in rows:
    print(row)



# Cerrar conexiones
cur.close()
conn.close()

print("------------------------------")

cursor = db.customers.find(
    {},
    {'first_name': 1,
     'last_name': 1,
     'total_spent': 1,
     'customer_id': 1,
     '_id': 0}
).sort('total_spent', -1)

for customer in cursor:
    print(f"({customer['customer_id']}, '{customer['first_name']}', '{customer['last_name']}', Decimal('{round(customer['total_spent'],2)}'))")
# Out:
# (59, 'Puja', 'Srivastava', Decimal('36.64'))
# (58, 'Manoj', 'Pareek', Decimal('38.62'))
# (57, 'Luis', 'Rojas', Decimal('46.62'))
# (56, 'Diego', 'Gutiérrez', Decimal('37.62'))
# (55, 'Mark', 'Taylor', Decimal('37.62'))
# (54, 'Steve', 'Murray', Decimal('37.62'))
# (53, 'Phil', 'Hughes', Decimal('37.62'))
# (52, 'Emma', 'Jones', Decimal('37.62'))
# (51, 'Joakim', 'Johansson', Decimal('38.62'))
# (50, 'Enrique', 'Muñoz', Decimal('37.62'))
# (49, 'Stanisław', 'Wójcik', Decimal('37.62'))
# (48, 'Johannes', 'Van der Berg', Decimal('40.62'))
# (47, 'Lucas', 'Mancini', Decimal('37.62'))
# (46, 'Hugh', "O'Reilly", Decimal('45.62'))
# (45, 'Ladislav', 'Kovács', Decimal('45.62'))
# (44, 'Terhi', 'Hämäläinen', Decimal('41.62'))
# (43, 'Isabelle', 'Mercier', Decimal('40.62'))
# (42, 'Wyatt', 'Girard', Decimal('39.62'))
# (41, 'Marc', 'Dubois', Decimal('37.62'))
# (40, 'Dominique', 'Lefebvre', Decimal('38.62'))
# (39, 'Camille', 'Bernard', Decimal('38.62'))
# (38, 'Niklas', 'Schröder', Decimal('37.62'))
# (37, 'Fynn', 'Zimmermann', Decimal('43.62'))
# (36, 'Hannah', 'Schneider', Decimal('37.62'))
# (35, 'Madalena', 'Sampaio', Decimal('37.62'))
# (34, 'João', 'Fernandes', Decimal('39.62'))
# (33, 'Ellie', 'Sullivan', Decimal('37.62'))
# (32, 'Aaron', 'Mitchell', Decimal('37.62'))
# (31, 'Martha', 'Silk', Decimal('37.62'))
# (30, 'Edward', 'Francis', Decimal('37.62'))
# (29, 'Robert', 'Brown', Decimal('37.62'))
# (28, 'Julia', 'Barnett', Decimal('43.62'))
# (27, 'Patrick', 'Gray', Decimal('37.62'))
# (26, 'Richard', 'Cunningham', Decimal('47.62'))
# (25, 'Victor', 'Stevens', Decimal('42.62'))
# (24, 'Frank', 'Ralston', Decimal('43.62'))
# (23, 'John', 'Gordon', Decimal('37.62'))
# (22, 'Heather', 'Leacock', Decimal('39.62'))
# (21, 'Kathy', 'Chase', Decimal('37.62'))
# (20, 'Dan', 'Miller', Decimal('39.62'))
# (19, 'Tim', 'Goyer', Decimal('38.62'))
# (18, 'Michelle', 'Brooks', Decimal('37.62'))
# (17, 'Jack', 'Smith', Decimal('39.62'))
# (16, 'Frank', 'Harris', Decimal('37.62'))
# (15, 'Jennifer', 'Peterson', Decimal('38.62'))
# (14, 'Mark', 'Philips', Decimal('37.62'))
# (13, 'Fernanda', 'Ramos', Decimal('37.62'))
# (12, 'Roberto', 'Almeida', Decimal('37.62'))
# (11, 'Alexandre', 'Rocha', Decimal('37.62'))
# (10, 'Eduardo', 'Martins', Decimal('37.62'))
# (9, 'Kara', 'Nielsen', Decimal('37.62'))
# (8, 'Daan', 'Peeters', Decimal('37.62'))
# (7, 'Astrid', 'Gruber', Decimal('42.62'))
# (6, 'Helena', 'Holý', Decimal('49.62'))
# (5, 'František', 'Wichterlová', Decimal('40.62'))
# (4, 'Bjørn', 'Hansen', Decimal('39.62'))
# (3, 'François', 'Tremblay', Decimal('39.62'))
# (2, 'Leonie', 'Köhler', Decimal('37.62'))
# (1, 'Luís', 'Gonçalves', Decimal('39.62'))
# ------------------------------
# (59, 'Puja', 'Srivastava', Decimal('36.64'))
# (58, 'Manoj', 'Pareek', Decimal('38.62'))
# (57, 'Luis', 'Rojas', Decimal('46.62'))
# (56, 'Diego', 'Gutiérrez', Decimal('37.62'))
# (55, 'Mark', 'Taylor', Decimal('37.62'))
# (54, 'Steve', 'Murray', Decimal('37.62'))
# (53, 'Phil', 'Hughes', Decimal('37.62'))
# (52, 'Emma', 'Jones', Decimal('37.62'))
# (51, 'Joakim', 'Johansson', Decimal('38.62'))
# (50, 'Enrique', 'Muñoz', Decimal('37.62'))
# (49, 'Stanisław', 'Wójcik', Decimal('37.62'))
# (48, 'Johannes', 'Van der Berg', Decimal('40.62'))
# (47, 'Lucas', 'Mancini', Decimal('37.62'))
# (46, 'Hugh', 'O'Reilly', Decimal('45.62'))
# (45, 'Ladislav', 'Kovács', Decimal('45.62'))
# (44, 'Terhi', 'Hämäläinen', Decimal('41.62'))
# (43, 'Isabelle', 'Mercier', Decimal('40.62'))
# (42, 'Wyatt', 'Girard', Decimal('39.62'))
# (41, 'Marc', 'Dubois', Decimal('37.62'))
# (40, 'Dominique', 'Lefebvre', Decimal('38.62'))
# (39, 'Camille', 'Bernard', Decimal('38.62'))
# (38, 'Niklas', 'Schröder', Decimal('37.62'))
# (37, 'Fynn', 'Zimmermann', Decimal('43.62'))
# (36, 'Hannah', 'Schneider', Decimal('37.62'))
# (35, 'Madalena', 'Sampaio', Decimal('37.62'))
# (34, 'João', 'Fernandes', Decimal('39.62'))
# (33, 'Ellie', 'Sullivan', Decimal('37.62'))
# (32, 'Aaron', 'Mitchell', Decimal('37.62'))
# (31, 'Martha', 'Silk', Decimal('37.62'))
# (30, 'Edward', 'Francis', Decimal('37.62'))
# (29, 'Robert', 'Brown', Decimal('37.62'))
# (28, 'Julia', 'Barnett', Decimal('43.62'))
# (27, 'Patrick', 'Gray', Decimal('37.62'))
# (26, 'Richard', 'Cunningham', Decimal('47.62'))
# (25, 'Victor', 'Stevens', Decimal('42.62'))
# (24, 'Frank', 'Ralston', Decimal('43.62'))
# (23, 'John', 'Gordon', Decimal('37.62'))
# (22, 'Heather', 'Leacock', Decimal('39.62'))
# (21, 'Kathy', 'Chase', Decimal('37.62'))
# (20, 'Dan', 'Miller', Decimal('39.62'))
# (19, 'Tim', 'Goyer', Decimal('38.62'))
# (18, 'Michelle', 'Brooks', Decimal('37.62'))
# (17, 'Jack', 'Smith', Decimal('39.62'))
# (16, 'Frank', 'Harris', Decimal('37.62'))
# (15, 'Jennifer', 'Peterson', Decimal('38.62'))
# (14, 'Mark', 'Philips', Decimal('37.62'))
# (13, 'Fernanda', 'Ramos', Decimal('37.62'))
# (12, 'Roberto', 'Almeida', Decimal('37.62'))
# (11, 'Alexandre', 'Rocha', Decimal('37.62'))
# (10, 'Eduardo', 'Martins', Decimal('37.62'))
# (9, 'Kara', 'Nielsen', Decimal('37.62'))
# (8, 'Daan', 'Peeters', Decimal('37.62'))
# (7, 'Astrid', 'Gruber', Decimal('42.62'))
# (6, 'Helena', 'Holý', Decimal('49.62'))
# (5, 'František', 'Wichterlová', Decimal('40.62'))
# (4, 'Bjørn', 'Hansen', Decimal('39.62'))
# (3, 'François', 'Tremblay', Decimal('39.62'))
# (2, 'Leonie', 'Köhler', Decimal('37.62'))
# (1, 'Luís', 'Gonçalves', Decimal('39.62'))

# %%
import psycopg2
# Mostrar cuales son las canciones mas vendidas de un genero determinado # Resultado da igual
# Conexión usando variables de entorno
conn = get_postgres_connection()
cur = conn.cursor()

# Ejecutar una consulta
cur.execute("""
    SELECT t.track_id, t.name, SUM(inl.unit_price * inl.quantity) as total from track t
    LEFT JOIN invoice_line inl on inl.track_id = t.track_id
    WHERE inl.unit_price * inl.quantity > 0 and t.genre_id = 3
    GROUP BY t.track_id, t.name
    ORDER BY total desc
""")
rows = cur.fetchall()

# Mostrar resultados
for row in rows:
    print(row)



# Cerrar conexiones
cur.close()
conn.close()

print("------------------------------")

genre_id = 3

results = db.tracks.find(
    {'genre_id': genre_id},
    {
        'name': 1,
        'sales.total_revenue': 1,
        '_id': 0,
        'track_id': 1
    }
).sort('sales.total_revenue', -1)

for track in results:
    # print(track);
    print(f"({track['track_id']}, '{track['name']}', Decimal('{track['sales']['total_revenue']}'))")
# Out:
# (162, 'Cornucopia', Decimal('1.98'))
# (184, 'Chemical Wedding', Decimal('1.98'))
# (1822, 'Stone Cold Crazy', Decimal('1.98'))
# (1389, 'Gangland', Decimal('1.98'))
# (1344, 'Aces High', Decimal('1.98'))
# (1888, 'Shoot Me Again', Decimal('1.98'))
# (416, 'Whiskey In The Jar', Decimal('1.98'))
# (2561, 'Question!', Decimal('1.98'))
# (1377, 'The Clairvoyant', Decimal('1.98'))
# (1841, 'The House Jack Built', Decimal('1.98'))
# (84, 'Welcome Home (Sanitarium)', Decimal('1.98'))
# (1865, 'Better Than You', Decimal('1.98'))
# (1358, 'Blood Brothers', Decimal('1.98'))
# (1876, 'For Whom The Bell Tolls', Decimal('1.98'))
# (1808, 'Nothing Else Matters', Decimal('1.98'))
# (1831, 'Motorbreath', Decimal('1.98'))
# (161, 'Snowblind', Decimal('1.98'))
# (1226, 'Can I Play With Madness', Decimal('1.98'))
# (1126, 'Re-Align', Decimal('1.98'))
# (1394, 'The Prisoner', Decimal('1.98'))
# (1331, 'Run Silent Run Deep', Decimal('1.98'))
# (1553, "You've Got Another Thing Comin'", Decimal('1.98'))
# (2560, 'Violent Pornography', Decimal('1.98'))
# (2108, 'Children Of The Grave', Decimal('1.98'))
# (1858, 'Leper Messiah', Decimal('1.98'))
# (1554, 'Turbo Lover', Decimal('1.98'))
# (1853, 'Battery', Decimal('1.98'))
# (1371, 'Moonchild', Decimal('1.98'))
# (1864, 'The Unforgiven II', Decimal('1.98'))
# (1335, 'Where Eagles Dare', Decimal('1.98'))
# (2554, 'Soldier Side - Intro', Decimal('1.98'))
# (1835, 'Phantom Lord', Decimal('1.98'))
# (1180, 'Breakdown', Decimal('1.98'))
# (3137, "Now You're Gone", Decimal('0.99'))
# (1124, 'Make Me Believe', Decimal('0.99'))
# (1857, 'Disposable Heroes', Decimal('0.99'))
# (2112, 'Dee', Decimal('0.99'))
# (1829, 'Hit The Lights', Decimal('0.99'))
# (1954, 'Dirty Love', Decimal('0.99'))
# (1232, 'Heaven Can Wait', Decimal('0.99'))
# (1945, 'Live To Win', Decimal('0.99'))
# (1819, 'Blitzkrieg', Decimal('0.99'))
# (1557, 'Metal Meltdown', Decimal('0.99'))
# (1849, 'Mama Said', Decimal('0.99'))
# (3136, 'Looking For Love', Decimal('0.99'))
# (2104, 'Relvelation (Mother Earth)', Decimal('0.99'))
# (1843, 'King Nothing', Decimal('0.99'))
# (1391, 'Invaders', Decimal('0.99'))
# (1383, 'Stranger in a Strange Land', Decimal('0.99'))
# (1345, '2 Minutes To Midnight', Decimal('0.99'))
# (1880, 'Creeping Death', Decimal('0.99'))
# (1121, 'Straight Out Of Line', Decimal('0.99'))
# (1213, 'The Trooper', Decimal('0.99'))
# (1882, 'Frantic', Decimal('0.99'))
# (1871, "Low Man's Lyric", Decimal('0.99'))
# (1803, 'Holier Than Thou', Decimal('0.99'))
# (1343, 'To Tame A Land', Decimal('0.99'))
# (1222, 'Iron Maiden', Decimal('0.99'))
# (1982, 'Primal Scream', Decimal('0.99'))
# (1374, 'The Evil That Men Do', Decimal('0.99'))
# (1813, 'Helpless', Decimal('0.99'))
# (1846, 'Cure', Decimal('0.99'))
# (152, 'N.I.B.', Decimal('0.99'))
# (1818, 'Am I Evil?', Decimal('0.99'))
# (1381, 'Sea of Madness', Decimal('0.99'))
# (1949, 'Jailbait', Decimal('0.99'))
# (193, 'Realword', Decimal('0.99'))
# (78, 'Master Of Puppets', Decimal('0.99'))
# (1325, 'Tailgunner', Decimal('0.99'))
# (1875, 'Ride The Lightning', Decimal('0.99'))
# (1356, 'Wrathchild', Decimal('0.99'))
# (186, 'Killing Floor', Decimal('0.99'))
# (2555, 'B.Y.O.B.', Decimal('0.99'))
# (2107, 'Iron Man', Decimal('0.99'))
# (1214, 'Prowler', Decimal('0.99'))
# (1347, 'Flash of The Blade', Decimal('0.99'))
# (1382, 'Heaven Can Wait', Decimal('0.99'))
# (1893, 'Blackened', Decimal('0.99'))
# (1852, 'The Outlaw Torn', Decimal('0.99'))
# (2101, 'Believer', Decimal('0.99'))
# (1231, 'Bring Your Daughter... To The Slaughter', Decimal('0.99'))
# (1950, 'Dance', Decimal('0.99'))
# (1900, 'To Live Is To Die', Decimal('0.99'))
# (2102, 'Mr. Crowley', Decimal('0.99'))
# (1392, 'Run to the Hills', Decimal('0.99'))
# (143, 'The Begining... At Last', Decimal('0.99'))
# (1549, "Hot Rockin'", Decimal('0.99'))
# (1845, 'Bleeding Me', Decimal('0.99'))
# (1181, 'Pretty Tied Up', Decimal('0.99'))
# (1838, 'Metal Militia', Decimal('0.99'))
# (1388, 'Children of the Damned', Decimal('0.99'))
# (80, 'The Unforgiven', Decimal('0.99'))
# (1817, 'Last Caress/Green Hell', Decimal('0.99'))
# (1804, 'The Unforgiven', Decimal('0.99'))
# (1861, 'Fuel', Decimal('0.99'))
# (1351, 'Rime of the Ancient Mariner', Decimal('0.99'))
# (1816, 'Crash Course In Brain Surgery', Decimal('0.99'))
# (1349, 'Back in the Village', Decimal('0.99'))
# (1333, 'Bring Your Daughter... ...To The Slaughter', Decimal('0.99'))
# (1973, 'Wild Side', Decimal('0.99'))
# (192, 'The Alchemist', Decimal('0.99'))
# (1174, 'Civil War', Decimal('0.99'))
# (1877, 'Fade To Black', Decimal('0.99'))
# (1815, 'The Wait', Decimal('0.99'))
# (1892, 'All Within My Hands', Decimal('0.99'))
# (1220, 'Run To The Hilss', Decimal('0.99'))
# (415, 'Astronomy', Decimal('0.99'))
# (1823, 'So What', Decimal('0.99'))
# (1886, 'Invisible Kid', Decimal('0.99'))
# (3142, 'The Deeper The Love', Decimal('0.99'))
# (1376, 'The Prophecy', Decimal('0.99'))
# (1299, 'Running Free', Decimal('0.99'))
# (1862, 'The Memory Remains', Decimal('0.99'))
# (1359, 'Sign Of The Cross', Decimal('0.99'))
# (1330, 'The Assassin', Decimal('0.99'))
# (1340, 'Still Life', Decimal('0.99'))
# (1826, 'Damage Case', Decimal('0.99'))
# (1329, 'Fates Warning', Decimal('0.99'))
# (1866, 'Slither', Decimal('0.99'))
# (153, 'Evil Woman', Decimal('0.99'))
# (147, 'Blood In The Wall', Decimal('0.99'))
# (1809, 'Of Wolf And Man', Decimal('0.99'))
# (1834, 'Whiplash', Decimal('0.99'))
# (412, 'Die Die My Darling', Decimal('0.99'))
# (1379, 'Caught Somewhere in Time', Decimal('0.99'))
# (1130, 'I Am', Decimal('0.99'))
# (1895, 'Eye Of The Beholder', Decimal('0.99'))
# (1390, 'Hallowed Be Thy Name', Decimal('0.99'))
# (1981, "Smokin' in The Boys Room", Decimal('0.99'))
# (1176, 'Yesterdays', Decimal('0.99'))
# (1814, 'The Small Hours', Decimal('0.99'))
# (2109, 'Paranoid', Decimal('0.99'))
# (1378, 'Only the Good Die Young', Decimal('0.99'))
# (1186, "Don't Cry", Decimal('0.99'))
# (1290, 'The Trooper', Decimal('0.99'))
# (1561, 'Tyrant (Live)', Decimal('0.99'))
# (1221, '2 Minutes To Midnight', Decimal('0.99'))
# (1227, 'Wasting Love', Decimal('0.99'))
# (1385, 'De Ja Vu', Decimal('0.99'))
# (1832, 'Jump In The Fire', Decimal('0.99'))
# (1295, 'The Number Of The Beast', Decimal('0.99'))
# (165, 'Under The Sun/Every Day Comes and Goes', Decimal('0.99'))
# (1820, 'Breadfan', Decimal('0.99'))
# (1555, 'Freewheel Burning', Decimal('0.99'))
# (1346, 'Losfer Words', Decimal('0.99'))
# (1217, 'Where Eagles Dare', Decimal('0.99'))
# (2562, 'Sad Statue', Decimal('0.99'))
# (1298, 'Run To The Hills', Decimal('0.99'))
# (138, 'Bored To Tears', Decimal('0.99'))
# (418, 'The More I See', Decimal('0.99'))
# (1870, 'Prince Charming', Decimal('0.99'))
# (1326, 'Holy Smoke', Decimal('0.99'))
# (1807, 'Through The Never', Decimal('0.99'))
# (1127, 'I Fucking Hate You', Decimal('0.99'))
# (1294, 'Powerslave', Decimal('0.99'))
# (1375, 'Seventh Son of a Seventh Son', Decimal('0.99'))
# (134, 'All For You', Decimal('0.99'))
# (3133, 'Here I Go Again', Decimal('0.99'))
# (144, 'Heart Of Gold', Decimal('0.99'))
# (1869, 'Where The Wild Things Are', Decimal('0.99'))
# (163, 'Laguna Sunrise', Decimal('0.99'))
# (3132, 'Still Of The Night', Decimal('0.99'))
# (2558, 'Radio/Video', Decimal('0.99'))
# (1837, 'Seek & Destroy', Decimal('0.99'))
# (1185, 'You Could Be Mine', Decimal('0.99'))
# (1842, 'Until It Sleeps', Decimal('0.99'))
# (1352, 'Intro', Decimal('0.99'))
# (1859, 'Orion', Decimal('0.99'))
# (1839, "Ain't My Bitch", Decimal('0.99'))
# (2103, 'Flying High Again', Decimal('0.99'))
# (1884, 'Some Kind Of Monster', Decimal('0.99'))
# (1887, 'My World', Decimal('0.99'))
# (1215, 'Transylvania', Decimal('0.99'))
# (157, "Tomorrow's Dream", Decimal('0.99'))
# (1559, 'Diamonds And Rust (Live)', Decimal('0.99'))
# (1327, 'No Prayer For The Dying', Decimal('0.99'))
# (183, 'King In Crimson', Decimal('0.99'))
# (1881, 'The Call Of Ktulu', Decimal('0.99'))
# (139, 'A.N.D.R.O.T.A.Z.', Decimal('0.99'))
# (411, 'Turn The Page', Decimal('0.99'))
# (1946, 'Fast And Loose', Decimal('0.99'))
# (1354, 'Ghost Of The Navigator', Decimal('0.99'))
# (191, 'Machine Men', Decimal('0.99'))
# (1976, "Same Ol' Situation", Decimal('0.99'))
# (1972, 'Kickstart My Heart', Decimal('0.99'))
# (1868, 'Bad Seed', Decimal('0.99'))
# (1355, 'Brave New World', Decimal('0.99'))
# (1350, 'Powerslave', Decimal('0.99'))
# (1812, 'The Struggle Within', Decimal('0.99'))
# (3145, 'Sweet Lady Luck', Decimal('0.99'))
# (1860, 'Damage Inc.', Decimal('0.99'))
# (2557, 'Cigaro', Decimal('0.99'))
# (185, 'The Tower', Decimal('0.99'))
# (1179, 'Shotgun Blues', Decimal('0.99'))
# (1847, 'Poor Twisted Me', Decimal('0.99'))
# (1955, "Please Don't Touch", Decimal('0.99'))
# (1339, 'The Trooper', Decimal('0.99'))
# (3141, "You're Gonna Break My Hart Again", Decimal('0.99'))
# (148, 'The Beginning...At Last', Decimal('0.99'))
# (1810, 'The God That Failed', Decimal('0.99'))
# (1855, 'The Thing That Should Not Be', Decimal('0.99'))
# (1977, 'Home Sweet Home', Decimal('0.99'))
# (2564, 'Lost in Hollywood', Decimal('0.99'))
# (1898, 'Harvester Of Sorrow', Decimal('0.99'))
# (190, 'Trupets Of Jericho', Decimal('0.99'))
# (1856, 'Welcome Home (Sanitarium)', Decimal('0.99'))
# (1899, 'The Frayed Ends Of Sanity', Decimal('0.99'))
# (1840, '2 X 4', Decimal('0.99'))
# (2556, 'Revenga', Decimal('0.99'))
# (1123, 'Changes', Decimal('0.99'))
# (1854, 'Master Of Puppets', Decimal('0.99'))
# (1348, 'Duelists', Decimal('0.99'))
# (1558, 'Ram It Down', Decimal('0.99'))
# (1811, 'My Friend Of Misery', Decimal('0.99'))
# (135, 'Super Terrorizer', Decimal('0.99'))
# (417, "Tuesday's Gone", Decimal('0.99'))
# (1894, '...And Justice For All', Decimal('0.99'))
# (1373, 'Can I Play With Madness', Decimal('0.99'))
# (1175, '14 Years', Decimal('0.99'))
# (1830, 'The Four Horsemen', Decimal('0.99'))
# (1833, '(Anesthesia) Pulling Teeth', Decimal('0.99'))
# (1872, 'Attitude', Decimal('0.99'))
# (189, 'Jerusalem', Decimal('0.99'))
# (1353, 'The Wicker Man', Decimal('0.99'))
# (188, 'Gates Of Urizen', Decimal('0.99'))
# (1122, 'Faceless', Decimal('0.99'))
# (1184, 'Estranged', Decimal('0.99'))
# (1985, 'Shout At The Devil', Decimal('0.99'))
# (1289, '2 Minutes To Midnight', Decimal('0.99'))
# (187, 'Book Of Thel', Decimal('0.99'))
# (2100, 'Crazy Train', Decimal('0.99'))
# ------------------------------
# (1864, 'The Unforgiven II', Decimal('1.98'))
# (1808, 'Nothing Else Matters', Decimal('1.98'))
# (1858, 'Leper Messiah', Decimal('1.98'))
# (1226, 'Can I Play With Madness', Decimal('1.98'))
# (184, 'Chemical Wedding', Decimal('1.98'))
# (1335, 'Where Eagles Dare', Decimal('1.98'))
# (1831, 'Motorbreath', Decimal('1.98'))
# (1389, 'Gangland', Decimal('1.98'))
# (1126, 'Re-Align', Decimal('1.98'))
# (1331, 'Run Silent Run Deep', Decimal('1.98'))
# (2108, 'Children Of The Grave', Decimal('1.98'))
# (1394, 'The Prisoner', Decimal('1.98'))
# (1865, 'Better Than You', Decimal('1.98'))
# (1553, 'You've Got Another Thing Comin'', Decimal('1.98'))
# (1554, 'Turbo Lover', Decimal('1.98'))
# (416, 'Whiskey In The Jar', Decimal('1.98'))
# (1822, 'Stone Cold Crazy', Decimal('1.98'))
# (161, 'Snowblind', Decimal('1.98'))
# (162, 'Cornucopia', Decimal('1.98'))
# (2561, 'Question!', Decimal('1.98'))
# (1358, 'Blood Brothers', Decimal('1.98'))
# (1841, 'The House Jack Built', Decimal('1.98'))
# (1371, 'Moonchild', Decimal('1.98'))
# (84, 'Welcome Home (Sanitarium)', Decimal('1.98'))
# (1888, 'Shoot Me Again', Decimal('1.98'))
# (1180, 'Breakdown', Decimal('1.98'))
# (1835, 'Phantom Lord', Decimal('1.98'))
# (1853, 'Battery', Decimal('1.98'))
# (2560, 'Violent Pornography', Decimal('1.98'))
# (1344, 'Aces High', Decimal('1.98'))
# (1377, 'The Clairvoyant', Decimal('1.98'))
# (1876, 'For Whom The Bell Tolls', Decimal('1.98'))
# (2554, 'Soldier Side - Intro', Decimal('1.98'))
# (1819, 'Blitzkrieg', Decimal('0.99'))
# (1816, 'Crash Course In Brain Surgery', Decimal('0.99'))
# (1804, 'The Unforgiven', Decimal('0.99'))
# (1820, 'Breadfan', Decimal('0.99'))
# (1817, 'Last Caress/Green Hell', Decimal('0.99'))
# (1818, 'Am I Evil?', Decimal('0.99'))
# (1815, 'The Wait', Decimal('0.99'))
# (1823, 'So What', Decimal('0.99'))
# (1826, 'Damage Case', Decimal('0.99'))
# (1829, 'Hit The Lights', Decimal('0.99'))
# (1830, 'The Four Horsemen', Decimal('0.99'))
# (1832, 'Jump In The Fire', Decimal('0.99'))
# (1833, '(Anesthesia) Pulling Teeth', Decimal('0.99'))
# (1834, 'Whiplash', Decimal('0.99'))
# (1837, 'Seek & Destroy', Decimal('0.99'))
# (1838, 'Metal Militia', Decimal('0.99'))
# (1839, 'Ain't My Bitch', Decimal('0.99'))
# (1840, '2 X 4', Decimal('0.99'))
# (1842, 'Until It Sleeps', Decimal('0.99'))
# (1843, 'King Nothing', Decimal('0.99'))
# (1376, 'The Prophecy', Decimal('0.99'))
# (1390, 'Hallowed Be Thy Name', Decimal('0.99'))
# (1388, 'Children of the Damned', Decimal('0.99'))
# (1385, 'De Ja Vu', Decimal('0.99'))
# (1383, 'Stranger in a Strange Land', Decimal('0.99'))
# (1382, 'Heaven Can Wait', Decimal('0.99'))
# (1381, 'Sea of Madness', Decimal('0.99'))
# (1379, 'Caught Somewhere in Time', Decimal('0.99'))
# (1378, 'Only the Good Die Young', Decimal('0.99'))
# (1391, 'Invaders', Decimal('0.99'))
# (1375, 'Seventh Son of a Seventh Son', Decimal('0.99'))
# (1374, 'The Evil That Men Do', Decimal('0.99'))
# (1373, 'Can I Play With Madness', Decimal('0.99'))
# (1359, 'Sign Of The Cross', Decimal('0.99'))
# (1356, 'Wrathchild', Decimal('0.99'))
# (1355, 'Brave New World', Decimal('0.99'))
# (1354, 'Ghost Of The Navigator', Decimal('0.99'))
# (1814, 'The Small Hours', Decimal('0.99'))
# (1392, 'Run to the Hills', Decimal('0.99'))
# (1549, 'Hot Rockin'', Decimal('0.99'))
# (1555, 'Freewheel Burning', Decimal('0.99'))
# (1557, 'Metal Meltdown', Decimal('0.99'))
# (1558, 'Ram It Down', Decimal('0.99'))
# (1559, 'Diamonds And Rust (Live)', Decimal('0.99'))
# (1561, 'Tyrant (Live)', Decimal('0.99'))
# (1803, 'Holier Than Thou', Decimal('0.99'))
# (1855, 'The Thing That Should Not Be', Decimal('0.99'))
# (1807, 'Through The Never', Decimal('0.99'))
# (1809, 'Of Wolf And Man', Decimal('0.99'))
# (1810, 'The God That Failed', Decimal('0.99'))
# (1811, 'My Friend Of Misery', Decimal('0.99'))
# (1812, 'The Struggle Within', Decimal('0.99'))
# (1813, 'Helpless', Decimal('0.99'))
# (1976, 'Same Ol' Situation', Decimal('0.99'))
# (2103, 'Flying High Again', Decimal('0.99'))
# (2102, 'Mr. Crowley', Decimal('0.99'))
# (2101, 'Believer', Decimal('0.99'))
# (2100, 'Crazy Train', Decimal('0.99'))
# (1985, 'Shout At The Devil', Decimal('0.99'))
# (1982, 'Primal Scream', Decimal('0.99'))
# (1981, 'Smokin' in The Boys Room', Decimal('0.99'))
# (1977, 'Home Sweet Home', Decimal('0.99'))
# (2104, 'Relvelation (Mother Earth)', Decimal('0.99'))
# (1973, 'Wild Side', Decimal('0.99'))
# (1972, 'Kickstart My Heart', Decimal('0.99'))
# (1955, 'Please Don't Touch', Decimal('0.99'))
# (1954, 'Dirty Love', Decimal('0.99'))
# (1950, 'Dance', Decimal('0.99'))
# (1949, 'Jailbait', Decimal('0.99'))
# (1946, 'Fast And Loose', Decimal('0.99'))
# (2562, 'Sad Statue', Decimal('0.99'))
# (3145, 'Sweet Lady Luck', Decimal('0.99'))
# (3142, 'The Deeper The Love', Decimal('0.99'))
# (3141, 'You're Gonna Break My Hart Again', Decimal('0.99'))
# (3137, 'Now You're Gone', Decimal('0.99'))
# (3136, 'Looking For Love', Decimal('0.99'))
# (3133, 'Here I Go Again', Decimal('0.99'))
# (3132, 'Still Of The Night', Decimal('0.99'))
# (2564, 'Lost in Hollywood', Decimal('0.99'))
# (1945, 'Live To Win', Decimal('0.99'))
# (2558, 'Radio/Video', Decimal('0.99'))
# (2557, 'Cigaro', Decimal('0.99'))
# (2556, 'Revenga', Decimal('0.99'))
# (2555, 'B.Y.O.B.', Decimal('0.99'))
# (2112, 'Dee', Decimal('0.99'))
# (2109, 'Paranoid', Decimal('0.99'))
# (2107, 'Iron Man', Decimal('0.99'))
# (1857, 'Disposable Heroes', Decimal('0.99'))
# (1870, 'Prince Charming', Decimal('0.99'))
# (1869, 'Where The Wild Things Are', Decimal('0.99'))
# (1868, 'Bad Seed', Decimal('0.99'))
# (1866, 'Slither', Decimal('0.99'))
# (1862, 'The Memory Remains', Decimal('0.99'))
# (1861, 'Fuel', Decimal('0.99'))
# (1860, 'Damage Inc.', Decimal('0.99'))
# (1859, 'Orion', Decimal('0.99'))
# (1871, 'Low Man's Lyric', Decimal('0.99'))
# (1856, 'Welcome Home (Sanitarium)', Decimal('0.99'))
# (78, 'Master Of Puppets', Decimal('0.99'))
# (1854, 'Master Of Puppets', Decimal('0.99'))
# (1852, 'The Outlaw Torn', Decimal('0.99'))
# (1849, 'Mama Said', Decimal('0.99'))
# (1847, 'Poor Twisted Me', Decimal('0.99'))
# (1846, 'Cure', Decimal('0.99'))
# (1886, 'Invisible Kid', Decimal('0.99'))
# (1900, 'To Live Is To Die', Decimal('0.99'))
# (1899, 'The Frayed Ends Of Sanity', Decimal('0.99'))
# (1898, 'Harvester Of Sorrow', Decimal('0.99'))
# (1895, 'Eye Of The Beholder', Decimal('0.99'))
# (1894, '...And Justice For All', Decimal('0.99'))
# (1893, 'Blackened', Decimal('0.99'))
# (1892, 'All Within My Hands', Decimal('0.99'))
# (1887, 'My World', Decimal('0.99'))
# (1845, 'Bleeding Me', Decimal('0.99'))
# (1884, 'Some Kind Of Monster', Decimal('0.99'))
# (1882, 'Frantic', Decimal('0.99'))
# (1881, 'The Call Of Ktulu', Decimal('0.99'))
# (1880, 'Creeping Death', Decimal('0.99'))
# (1877, 'Fade To Black', Decimal('0.99'))
# (1875, 'Ride The Lightning', Decimal('0.99'))
# (1872, 'Attitude', Decimal('0.99'))
# (1220, 'Run To The Hilss', Decimal('0.99'))
# (1176, 'Yesterdays', Decimal('0.99'))
# (157, 'Tomorrow's Dream', Decimal('0.99'))
# (1179, 'Shotgun Blues', Decimal('0.99'))
# (1181, 'Pretty Tied Up', Decimal('0.99'))
# (1184, 'Estranged', Decimal('0.99'))
# (1185, 'You Could Be Mine', Decimal('0.99'))
# (1186, 'Don't Cry', Decimal('0.99'))
# (1213, 'The Trooper', Decimal('0.99'))
# (1214, 'Prowler', Decimal('0.99'))
# (1215, 'Transylvania', Decimal('0.99'))
# (1217, 'Where Eagles Dare', Decimal('0.99'))
# (153, 'Evil Woman', Decimal('0.99'))
# (1175, '14 Years', Decimal('0.99'))
# (1221, '2 Minutes To Midnight', Decimal('0.99'))
# (152, 'N.I.B.', Decimal('0.99'))
# (1222, 'Iron Maiden', Decimal('0.99'))
# (1227, 'Wasting Love', Decimal('0.99'))
# (148, 'The Beginning...At Last', Decimal('0.99'))
# (1231, 'Bring Your Daughter... To The Slaughter', Decimal('0.99'))
# (1232, 'Heaven Can Wait', Decimal('0.99'))
# (147, 'Blood In The Wall', Decimal('0.99'))
# (1289, '2 Minutes To Midnight', Decimal('0.99'))
# (1290, 'The Trooper', Decimal('0.99'))
# (144, 'Heart Of Gold', Decimal('0.99'))
# (143, 'The Begining... At Last', Decimal('0.99'))
# (412, 'Die Die My Darling', Decimal('0.99'))
# (189, 'Jerusalem', Decimal('0.99'))
# (188, 'Gates Of Urizen', Decimal('0.99'))
# (190, 'Trupets Of Jericho', Decimal('0.99'))
# (191, 'Machine Men', Decimal('0.99'))
# (192, 'The Alchemist', Decimal('0.99'))
# (187, 'Book Of Thel', Decimal('0.99'))
# (193, 'Realword', Decimal('0.99'))
# (186, 'Killing Floor', Decimal('0.99'))
# (185, 'The Tower', Decimal('0.99'))
# (183, 'King In Crimson', Decimal('0.99'))
# (165, 'Under The Sun/Every Day Comes and Goes', Decimal('0.99'))
# (411, 'Turn The Page', Decimal('0.99'))
# (1352, 'Intro', Decimal('0.99'))
# (415, 'Astronomy', Decimal('0.99'))
# (417, 'Tuesday's Gone', Decimal('0.99'))
# (418, 'The More I See', Decimal('0.99'))
# (1121, 'Straight Out Of Line', Decimal('0.99'))
# (1122, 'Faceless', Decimal('0.99'))
# (1123, 'Changes', Decimal('0.99'))
# (1124, 'Make Me Believe', Decimal('0.99'))
# (163, 'Laguna Sunrise', Decimal('0.99'))
# (1127, 'I Fucking Hate You', Decimal('0.99'))
# (1130, 'I Am', Decimal('0.99'))
# (1174, 'Civil War', Decimal('0.99'))
# (1345, '2 Minutes To Midnight', Decimal('0.99'))
# (134, 'All For You', Decimal('0.99'))
# (1339, 'The Trooper', Decimal('0.99'))
# (135, 'Super Terrorizer', Decimal('0.99'))
# (1329, 'Fates Warning', Decimal('0.99'))
# (1340, 'Still Life', Decimal('0.99'))
# (1327, 'No Prayer For The Dying', Decimal('0.99'))
# (1343, 'To Tame A Land', Decimal('0.99'))
# (138, 'Bored To Tears', Decimal('0.99'))
# (1330, 'The Assassin', Decimal('0.99'))
# (1294, 'Powerslave', Decimal('0.99'))
# (1326, 'Holy Smoke', Decimal('0.99'))
# (1325, 'Tailgunner', Decimal('0.99'))
# (1299, 'Running Free', Decimal('0.99'))
# (1346, 'Losfer Words', Decimal('0.99'))
# (1347, 'Flash of The Blade', Decimal('0.99'))
# (139, 'A.N.D.R.O.T.A.Z.', Decimal('0.99'))
# (80, 'The Unforgiven', Decimal('0.99'))
# (1348, 'Duelists', Decimal('0.99'))
# (1333, 'Bring Your Daughter... ...To The Slaughter', Decimal('0.99'))
# (1351, 'Rime of the Ancient Mariner', Decimal('0.99'))
# (1298, 'Run To The Hills', Decimal('0.99'))
# (1353, 'The Wicker Man', Decimal('0.99'))
# (1350, 'Powerslave', Decimal('0.99'))
# (1349, 'Back in the Village', Decimal('0.99'))
# (1295, 'The Number Of The Beast', Decimal('0.99'))
# (2563, 'Old School Hollywood', Decimal('0.0'))
# (81, 'Sad But True', Decimal('0.0'))
# (82, 'Creeping Death', Decimal('0.0'))
# (1947, '(We Are) The Road Crew', Decimal('0.0'))
# (1951, 'Bite The Bullet', Decimal('0.0'))
# (3135, 'Love Ain't No Stranger', Decimal('0.0'))
# (159, 'FX', Decimal('0.0'))
# (3134, 'Is This Love', Decimal('0.0'))
# (160, 'Supernaut', Decimal('0.0'))
# (1948, 'Fire Fire', Decimal('0.0'))
# (83, 'Wherever I May Roam', Decimal('0.0'))
# (3138, 'Slide It In', Decimal('0.0'))
# (164, 'St. Vitus Dance', Decimal('0.0'))
# (3139, 'Slow An' Easy', Decimal('0.0'))
# (3140, 'Judgement Day', Decimal('0.0'))
# (1944, 'Shoot You In The Back', Decimal('0.0'))
# (1943, 'Love Me Like A Reptile', Decimal('0.0'))
# (1942, 'Ace Of Spades', Decimal('0.0'))
# (1901, 'Dyers Eve', Decimal('0.0'))
# (1897, 'The Shortest Straw', Decimal('0.0'))
# (1896, 'One', Decimal('0.0'))
# (79, 'Harvester Of Sorrow', Decimal('0.0'))
# (3143, 'Crying In The Rain', Decimal('0.0'))
# (3144, 'Fool For Your Loving', Decimal('0.0'))
# (77, 'Enter Sandman', Decimal('0.0'))
# (140, 'Born To Booze', Decimal('0.0'))
# (1979, 'Don't Go Away Mad (Just Go Away)', Decimal('0.0'))
# (1980, 'Without You', Decimal('0.0'))
# (151, 'Behind The Wall Of Sleep', Decimal('0.0'))
# (1983, 'Too Fast For Love', Decimal('0.0'))
# (1984, 'Looks That Kill', Decimal('0.0'))
# (150, 'The Wizard', Decimal('0.0'))
# (2099, 'I Don't Know', Decimal('0.0'))
# (149, 'Black Sabbath', Decimal('0.0'))
# (1978, 'Afraid', Decimal('0.0'))
# (141, 'World Of Trouble', Decimal('0.0'))
# (2111, 'No Bone Movies', Decimal('0.0'))
# (146, 'Like A Bird', Decimal('0.0'))
# (2110, 'Goodbye To Romance', Decimal('0.0'))
# (145, 'Snowblind', Decimal('0.0'))
# (2105, 'Steal Away (The Night)', Decimal('0.0'))
# (2106, 'Suicide Solution (With Guitar Solo)', Decimal('0.0'))
# (142, 'No More Tears', Decimal('0.0'))
# (133, 'Stronger Than Death', Decimal('0.0'))
# (132, '13 Years Of Grief', Decimal('0.0'))
# (1952, 'The Chase Is Better Than The Catch', Decimal('0.0'))
# (1953, 'The Hammer', Decimal('0.0'))
# (158, 'Changes', Decimal('0.0'))
# (1956, 'Emergency', Decimal('0.0'))
# (1969, 'Bitter Pill', Decimal('0.0'))
# (1970, 'Enslaved', Decimal('0.0'))
# (1971, 'Girls, Girls, Girls', Decimal('0.0'))
# (131, 'Intro/ Low Down', Decimal('0.0'))
# (156, 'Wheels Of Confusion / The Straightener', Decimal('0.0'))
# (155, 'Warning', Decimal('0.0'))
# (1974, 'Glitter', Decimal('0.0'))
# (2559, 'This Cocaine Makes Me Feel Like I'm On This Song', Decimal('0.0'))
# (1975, 'Dr. Feelgood', Decimal('0.0'))
# (136, 'Phoney Smile Fake Hellos', Decimal('0.0'))
# (154, 'Sleeping Village', Decimal('0.0'))
# (137, 'Lost My Better Half', Decimal('0.0'))
# (1805, 'Wherever I May Roam', Decimal('0.0'))
# (1550, 'Heading Out To The Highway (Live)', Decimal('0.0'))
# (1551, 'The Hellion', Decimal('0.0'))
# (1552, 'Electric Eye', Decimal('0.0'))
# (1556, 'Some Heads Are Gonna Roll', Decimal('0.0'))
# (1297, 'Iron Maiden', Decimal('0.0'))
# (1296, 'Hallowed Be Thy Name', Decimal('0.0'))
# (1560, 'Victim Of Change (Live)', Decimal('0.0'))
# (1801, 'Enter Sandman', Decimal('0.0'))
# (1802, 'Sad But True', Decimal('0.0'))
# (1293, 'Rime Of The Ancient Mariner', Decimal('0.0'))
# (1548, 'Breaking The Law (Live)', Decimal('0.0'))
# (1806, 'Don't Tread On Me', Decimal('0.0'))
# (1292, 'Flight Of Icarus', Decimal('0.0'))
# (1291, 'Revelations', Decimal('0.0'))
# (1234, 'Fear Of The Dark', Decimal('0.0'))
# (1233, 'The Clairvoyant', Decimal('0.0'))
# (1230, 'Afraid To Shoot Strangers', Decimal('0.0'))
# (1229, 'The Evil That Men Do', Decimal('0.0'))
# (1228, 'Tailgunner', Decimal('0.0'))
# (1225, 'From Here To Eternity', Decimal('0.0'))
# (1337, 'Flight Of The Icarus', Decimal('0.0'))
# (1357, '2 Minutes To Midnight', Decimal('0.0'))
# (1360, 'The Mercenary', Decimal('0.0'))
# (1361, 'The Trooper', Decimal('0.0'))
# (1364, 'The Evil That Men Do', Decimal('0.0'))
# (1372, 'Infinite Dreams', Decimal('0.0'))
# (1342, 'Sun And Steel', Decimal('0.0'))
# (1341, 'Quest For Fire', Decimal('0.0'))
# (1380, 'Wasted Years', Decimal('0.0'))
# (1338, 'Die With Your Boots On', Decimal('0.0'))
# (1224, 'Be Quick Or Be Dead', Decimal('0.0'))
# (1384, 'Alexander the Great', Decimal('0.0'))
# (1336, 'Revelations', Decimal('0.0'))
# (1386, 'The Loneliness of the Long Dis', Decimal('0.0'))
# (1387, '22 Acacia Avenue', Decimal('0.0'))
# (1334, 'Mother Russia', Decimal('0.0'))
# (1332, 'Hooks In You', Decimal('0.0'))
# (1328, 'Public Enema Number One', Decimal('0.0'))
# (1546, 'The Green Manalishi', Decimal('0.0'))
# (1547, 'Living After Midnight', Decimal('0.0'))
# (413, 'Loverman', Decimal('0.0'))
# (1132, 'Serenity', Decimal('0.0'))
# (1131, 'The Awakening', Decimal('0.0'))
# (1129, 'Dead And Broken', Decimal('0.0'))
# (1128, 'Releasing The Demons', Decimal('0.0'))
# (1125, 'I Stand Alone', Decimal('0.0'))
# (1863, 'Devil's Dance', Decimal('0.0'))
# (1867, 'Carpe Diem Baby', Decimal('0.0'))
# (414, 'Mercyful Fate', Decimal('0.0'))
# (1873, 'Fixxxer', Decimal('0.0'))
# (1874, 'Fight Fire With Fire', Decimal('0.0'))
# (1177, 'Knockin' On Heaven's Door', Decimal('0.0'))
# (1878, 'Trapped Under Ice', Decimal('0.0'))
# (1879, 'Escape', Decimal('0.0'))
# (410, 'Sabbra Cadabra', Decimal('0.0'))
# (409, 'It's Electric', Decimal('0.0'))
# (408, 'Free Speech For The Dumb', Decimal('0.0'))
# (1883, 'St. Anger', Decimal('0.0'))
# (1885, 'Dirty Window', Decimal('0.0'))
# (1889, 'Sweet Amber', Decimal('0.0'))
# (1890, 'The Unnamed Feeling', Decimal('0.0'))
# (1836, 'No Remorse', Decimal('0.0'))
# (1821, 'The Prince', Decimal('0.0'))
# (1223, 'Hallowed Be Thy Name', Decimal('0.0'))
# (1824, 'Killing Time', Decimal('0.0'))
# (1825, 'Overkill', Decimal('0.0'))
# (1827, 'Stone Dead Forever', Decimal('0.0'))
# (1828, 'Too Late Too Late', Decimal('0.0'))
# (1219, 'Running Free', Decimal('0.0'))
# (1218, 'Sanctuary', Decimal('0.0'))
# (1216, 'Remember Tomorrow', Decimal('0.0'))
# (1891, 'Purify', Decimal('0.0'))
# (1212, 'The Number Of The Beast', Decimal('0.0'))
# (1187, 'My World', Decimal('0.0'))
# (1183, 'So Fine', Decimal('0.0'))
# (1844, 'Hero Of The Day', Decimal('0.0'))
# (1182, 'Locomotive', Decimal('0.0'))
# (1848, 'Wasted My Hate', Decimal('0.0'))
# (1178, 'Get In The Ring', Decimal('0.0'))
# (1850, 'Thorn Within', Decimal('0.0'))
# (1851, 'Ronnie', Decimal('0.0'))

# %%
import psycopg2
# Mostrar las canciones mas vendidos de un pais # Resultado da igual
# Conexión usando variables de entorno
conn = get_postgres_connection()
cur = conn.cursor()

# Ejecutar una consulta
cur.execute("""
    SELECT t.track_id, t.name, SUM(inl.unit_price * inl.quantity) as total from track t
    LEFT JOIN invoice_line inl on inl.track_id = t.track_id
    LEFT JOIN invoice inv on inv.invoice_id = inl.invoice_id
    WHERE inl.unit_price * inl.quantity > 0 and inv.billing_country = 'USA'
    GROUP BY t.track_id, t.name
    ORDER BY total desc
""")
rows = cur.fetchall()

# Mostrar resultados
for row in rows:
    print(row)



# Cerrar conexiones
cur.close()
conn.close()
print("------------------------------")
country = 'USA'

pipeline = [
    {"$match": {"invoices.billing_country": country}},
    {"$unwind": "$invoices"},
    {"$unwind": "$invoices.invoice_lines"},
    {"$group": {
        "_id": "$invoices.invoice_lines.track_id",
        "total_invoice_value": {
            "$sum": {
                "$multiply": [
                    "$invoices.invoice_lines.quantity",
                    "$invoices.invoice_lines.unit_price"
                ]
            }
        }
    }},
    {"$lookup": {
        "from": "tracks",
        "localField": "_id",
        "foreignField": "track_id",
        "as": "track_info"
    }},
    {"$unwind": "$track_info"},
    {"$project": {
        "_id": 0,
        "track_id": "$_id",
        "track_name": "$track_info.name",
        "total_invoice_value": 1
    }},
    {"$sort": {"total_invoice_value": -1}}
]

results = db.customers.aggregate(pipeline)

for result in results:
    print(f"({result['track_id']}, '{result['track_name']}', Decimal('{result['total_invoice_value']})")
# Out:
# (3200, 'Gay Witch Hunt', Decimal('3.98'))
# (3173, 'Diversity Day', Decimal('1.99'))
# (3191, 'The Carpet', Decimal('1.99'))
# (2837, 'Crossroads, Pt. 1', Decimal('1.99'))
# (3218, 'Safety Training', Decimal('1.99'))
# (2828, 'The Passage', Decimal('1.99'))
# (3222, 'The Job', Decimal('1.99'))
# (2918, '"?"', Decimal('1.99'))
# (2882, 'Lost Survival Guide', Decimal('1.99'))
# (3230, 'Lost Planet of the Gods, Pt. 2', Decimal('1.99'))
# (2900, 'Exposé', Decimal('1.99'))
# (3212, "Producer's Cut: The Return", Decimal('1.99'))
# (2891, 'Enter 77', Decimal('1.99'))
# (3214, "Phyllis's Wedding", Decimal('1.99'))
# (3208, 'The Convict', Decimal('1.99'))
# (3238, 'The Living Legend, Pt. 2', Decimal('1.99'))
# (3182, 'Halloween', Decimal('1.99'))
# (2846, 'Seven Minutes to Midnight', Decimal('1.99'))
# (3428, 'Branch Closing', Decimal('1.99'))
# (2909, 'Catch-22', Decimal('1.99'))
# (2864, 'Orientation', Decimal('1.99'))
# (2873, 'House of the Rising Sun', Decimal('1.99'))
# (3202, 'The Coup', Decimal('1.99'))
# (3347, 'Meet Kevin Johnson', Decimal('1.99'))
# (3209, 'A Benihana Christmas, Pts. 1 & 2', Decimal('1.99'))
# (2822, 'Exodus, Pt. 2', Decimal('1.99'))
# (3210, 'Back from Vacation', Decimal('1.99'))
# (2855, 'Company Man', Decimal('1.99'))
# (3206, 'Branch Closing', Decimal('1.99'))
# (3226, 'Battlestar Galactica, Pt. 1', Decimal('1.99'))
# (3204, 'The Initiation', Decimal('1.99'))
# (3234, 'The Gun On Ice Planet Zero, Pt. 2', Decimal('1.99'))
# (3201, 'The Convention', Decimal('1.99'))
# (2600, 'Train In Vain', Decimal('1.98'))
# (2618, 'Speed Of Light', Decimal('1.98'))
# (207, 'Meditação', Decimal('1.98'))
# (2759, 'Música No Ar', Decimal('1.98'))
# (2945, 'Peace On Earth', Decimal('1.98'))
# (2636, 'Sun King', Decimal('1.98'))
# (3455, 'Rehab', Decimal('1.98'))
# (1119, 'Toda Menina Baiana', Decimal('0.99'))
# (2065, 'Trac Trac', Decimal('0.99'))
# (2504, 'Real Love', Decimal('0.99'))
# (357, 'Advance Romance', Decimal('0.99'))
# (913, 'Lonely Stranger', Decimal('0.99'))
# (2543, 'Sex Type Thing', Decimal('0.99'))
# (1829, 'Hit The Lights', Decimal('0.99'))
# (366, 'Camisa Verde 2001', Decimal('0.99'))
# (2690, 'Love Is Strong', Decimal('0.99'))
# (1841, 'The House Jack Built', Decimal('0.99'))
# (1232, 'Heaven Can Wait', Decimal('0.99'))
# (3457, 'Me & Mr. Jones', Decimal('0.99'))
# (2765, 'Réu Confesso', Decimal('0.99'))
# (466, 'J Squared', Decimal('0.99'))
# (1617, 'When The Levee Breaks', Decimal('0.99'))
# (1940, 'Norwegian Wood', Decimal('0.99'))
# (3473, 'Take the Box', Decimal('0.99'))
# (2063, 'Nebulosa Do Amor', Decimal('0.99'))
# (1196, 'Millenium', Decimal('0.99'))
# (1163, "You Ain't the First", Decimal('0.99'))
# (2514, 'Spoonman', Decimal('0.99'))
# (2773, 'Padre Cícero', Decimal('0.99'))
# (822, 'A Twist In The Tail', Decimal('0.99'))
# (219, 'Odara', Decimal('0.99'))
# (2630, 'Edie (Ciao Baby)', Decimal('0.99'))
# (241, 'Geni E O Zepelim', Decimal('0.99'))
# (285, 'Soldado Da Paz', Decimal('0.99'))
# (1880, 'Creeping Death', Decimal('0.99'))
# (3446, "Symphonie Fantastique, Op. 14: V. Songe d'une nuit du sabbat", Decimal('0.99'))
# (66, 'Por Causa De Você', Decimal('0.99'))
# (2351, 'Todo Mundo Explica', Decimal('0.99'))
# (3018, 'Sunday Bloody Sunday', Decimal('0.99'))
# (3077, "Can't Stop Loving You", Decimal('0.99'))
# (1803, 'Holier Than Thou', Decimal('0.99'))
# (1922, 'Menestrel Das Alagoas', Decimal('0.99'))
# (1053, 'Bad, Bad Leroy Brown', Decimal('0.99'))
# (75, 'O Boto (Bôto)', Decimal('0.99'))
# (3164, 'Verdade', Decimal('0.99'))
# (2609, 'War (The Process)', Decimal('0.99'))
# (735, 'Metrô. Linha 743', Decimal('0.99'))
# (2672, 'Paint It Black', Decimal('0.99'))
# (909, 'Signe', Decimal('0.99'))
# (1685, 'O Livro Dos Dias', Decimal('0.99'))
# (3461, 'Tears Dry On Their Own', Decimal('0.99'))
# (1008, 'Razor', Decimal('0.99'))
# (1098, 'Copacabana (Live)', Decimal('0.99'))
# (217, 'Mel', Decimal('0.99'))
# (2555, 'B.Y.O.B.', Decimal('0.99'))
# (1679, 'Dezesseis', Decimal('0.99'))
# (977, 'Xote Dos Milagres', Decimal('0.99'))
# (3047, 'Bring Me Your Cup', Decimal('0.99'))
# (496, 'Living On Love', Decimal('0.99'))
# (3463, 'Some Unholy War', Decimal('0.99'))
# (294, 'Pensamento', Decimal('0.99'))
# (1388, 'Children of the Damned', Decimal('0.99'))
# (229, 'Samba De Orly', Decimal('0.99'))
# (1629, 'The Lemon Song', Decimal('0.99'))
# (2763, 'Compadre', Decimal('0.99'))
# (3481, "A Midsummer Night's Dream, Op.61 Incidental Music: No.7 Notturno", Decimal('0.99'))
# (2687, 'Thief In The Night', Decimal('0.99'))
# (405, 'Santo Antonio', Decimal('0.99'))
# (84, 'Welcome Home (Sanitarium)', Decimal('0.99'))
# (762, 'No No No', Decimal('0.99'))
# (1877, 'Fade To Black', Decimal('0.99'))
# (1815, 'The Wait', Decimal('0.99'))
# (1044, 'My Kind Of Town', Decimal('0.99'))
# (2369, 'Naked In The Rain', Decimal('0.99'))
# (1062, 'Zambação', Decimal('0.99'))
# (375, 'Mas Que Nada', Decimal('0.99'))
# (983, 'Principiando/Decolagem', Decimal('0.99'))
# (415, 'Astronomy', Decimal('0.99'))
# (1823, 'So What', Decimal('0.99'))
# (108, 'Dandelion', Decimal('0.99'))
# (1835, 'Phantom Lord', Decimal('0.99'))
# (682, 'Down On The Corner', Decimal('0.99'))
# (674, 'Preciso Apender a Viver Só (Maysa)', Decimal('0.99'))
# (567, 'Tradição', Decimal('0.99'))
# (630, 'Boogie Blues', Decimal('0.99'))
# (401, 'Momentos Que Marcam', Decimal('0.99'))
# (816, 'The Battle Rages On', Decimal('0.99'))
# (3467, 'Intro / Stronger Than Me', Decimal('0.99'))
# (153, 'Evil Woman', Decimal('0.99'))
# (2951, 'Sweetest Thing', Decimal('0.99'))
# (419, 'A Kind Of Magic', Decimal('0.99'))
# (903, 'Lay Down Sally', Decimal('0.99'))
# (3041, 'Homely Girl', Decimal('0.99'))
# (3035, 'The First Time', Decimal('0.99'))
# (2760, 'Salve Nossa Senhora', Decimal('0.99'))
# (3383, 'Scar On the Sky', Decimal('0.99'))
# (1170, "Don't Damn Me", Decimal('0.99'))
# (3392, 'Until We Fall', Decimal('0.99'))
# (965, 'Epic', Decimal('0.99'))
# (1250, 'Gates Of Tomorrow', Decimal('0.99'))
# (2663, 'Message in a Bottle (new classic rock mix)', Decimal('0.99'))
# (2798, 'Homem Primata', Decimal('0.99'))
# (2567, 'Duende', Decimal('0.99'))
# (30, 'Amazing', Decimal('0.99'))
# (840, 'Hysteria', Decimal('0.99'))
# (2324, 'Pretty Persuasion', Decimal('0.99'))
# (3101, 'Primary', Decimal('0.99'))
# (2345, 'O Dia Em Que A Terra Parou', Decimal('0.99'))
# (1378, 'Only the Good Die Young', Decimal('0.99'))
# (981, 'Zeca Violeiro', Decimal('0.99'))
# (921, 'Old Love', Decimal('0.99'))
# (2510, 'Get On The Snake', Decimal('0.99'))
# (3469, 'F**k Me Pumps', Decimal('0.99'))
# (2645, 'Back Door Man', Decimal('0.99'))
# (2780, 'Formigueiro', Decimal('0.99'))
# (3059, 'Little Guitars (Intro)', Decimal('0.99'))
# (639, "Don't Take Your Love From Me", Decimal('0.99'))
# (209, 'Eclipse Oculto', Decimal('0.99'))
# (937, 'Midlife Crisis', Decimal('0.99'))
# (894, 'Sunshine Of Your Love', Decimal('0.99'))
# (138, 'Bored To Tears', Decimal('0.99'))
# (2741, 'Pinball Wizard', Decimal('0.99'))
# (245, 'Construção / Deus Lhe Pague', Decimal('0.99'))
# (3155, 'Sem Essa de Malandro Agulha', Decimal('0.99'))
# (947, 'Midnight Cowboy', Decimal('0.99'))
# (407, 'Só Tinha De Ser Com Você', Decimal('0.99'))
# (1326, 'Holy Smoke', Decimal('0.99'))
# (3374, 'All Night Thing', Decimal('0.99'))
# (3016, 'Angel Of Harlem', Decimal('0.99'))
# (1807, 'Through The Never', Decimal('0.99'))
# (1127, 'I Fucking Hate You', Decimal('0.99'))
# (2084, 'O Beco', Decimal('0.99'))
# (1017, 'Overdrive', Decimal('0.99'))
# (484, 'Nice Guys Finish Last', Decimal('0.99'))
# (558, 'Viradouro', Decimal('0.99'))
# (2651, "Can't Stand Losing You", Decimal('0.99'))
# (144, 'Heart Of Gold', Decimal('0.99'))
# (1071, 'Divirta-Se (Saindo Da Sua)', Decimal('0.99'))
# (540, 'Posso Perder Minha Mulher, Minha Mãe, Desde Que Eu Tenha O Rock And Roll', Decimal('0.99'))
# (39, 'You Oughta Know', Decimal('0.99'))
# (2505, '[Untitled]', Decimal('0.99'))
# (2531, 'End Of Romanticism', Decimal('0.99'))
# (2594, 'Clash City Rockers', Decimal('0.99'))
# (1424, 'Hey America', Decimal('0.99'))
# (393, 'Tarde Em Itapoã', Decimal('0.99'))
# (464, 'As We Sleep', Decimal('0.99'))
# (312, 'Eu Também Quero Beijar', Decimal('0.99'))
# (1151, 'Paradise City', Decimal('0.99'))
# (2516, 'Black Hole Sun', Decimal('0.99'))
# (1859, 'Orion', Decimal('0.99'))
# (662, 'Pela Luz dos Olhos Teus (Miúcha e Tom Jobim)', Decimal('0.99'))
# (1254, 'Age Of Innocence', Decimal('0.99'))
# (1133, 'American Idiot', Decimal('0.99'))
# (2681, 'Corinna', Decimal('0.99'))
# (488, "Macy's Day Parade", Decimal('0.99'))
# (2255, 'Another One Bites The Dust', Decimal('0.99'))
# (1101, 'De Ouro E Marfim (Live)', Decimal('0.99'))
# (126, 'Moon germs', Decimal('0.99'))
# (463, 'Believe', Decimal('0.99'))
# (2955, 'Everlasting Love', Decimal('0.99'))
# (2096, 'Flying High Again', Decimal('0.99'))
# (476, 'Geek Stink Breath', Decimal('0.99'))
# (99, 'Your Time Has Come', Decimal('0.99'))
# (1035, 'New York, New York', Decimal('0.99'))
# (726, 'Palavras Ao Vento', Decimal('0.99'))
# (2591, 'White Riot', Decimal('0.99'))
# (2804, 'Lugar Nenhum', Decimal('0.99'))
# (1412, "Don't Look To The Eyes Of A Stranger", Decimal('0.99'))
# (2250, 'Nega Do Cabelo Duro', Decimal('0.99'))
# (933, 'Home Sick Home', Decimal('0.99'))
# (423, 'I Want To Break Free', Decimal('0.99'))
# (1238, 'Blood Brothers', Decimal('0.99'))
# (2959, 'Hallelujah Here She Comes', Decimal('0.99'))
# (1621, 'Dazed and Confused', Decimal('0.99'))
# (411, 'Turn The Page', Decimal('0.99'))
# (1946, 'Fast And Loose', Decimal('0.99'))
# (1808, 'Nothing Else Matters', Decimal('0.99'))
# (2339, 'Puteiro Em João Pessoa', Decimal('0.99'))
# (3419, 'Requiem, Op.48: 4. Pie Jesu', Decimal('0.99'))
# (825, "One Man's Meat", Decimal('0.99'))
# (657, 'Deixa', Decimal('0.99'))
# (403, 'Bumbo Da Mangueira', Decimal('0.99'))
# (3065, "Ain't Talkin' 'bout Love", Decimal('0.99'))
# (474, 'She', Decimal('0.99'))
# (3459, 'Back to Black', Decimal('0.99'))
# (654, 'Minha Namorada', Decimal('0.99'))
# (3015, 'When Love Comes To Town', Decimal('0.99'))
# (1643, "That's The Way", Decimal('0.99'))
# (885, 'Fascinação', Decimal('0.99'))
# (549, 'You Fool No One', Decimal('0.99'))
# (1910, 'Lament', Decimal('0.99'))
# (1847, 'Poor Twisted Me', Decimal('0.99'))
# (215, 'Sozinho', Decimal('0.99'))
# (1107, 'Refazenda', Decimal('0.99'))
# (2954, 'Dancing Barefoot', Decimal('0.99'))
# (1157, 'Rocket Queen', Decimal('0.99'))
# (612, 'Nefertiti', Decimal('0.99'))
# (384, 'Mistério da Raça', Decimal('0.99'))
# (2582, 'Black Moon Creeping', Decimal('0.99'))
# (1145, 'Whatsername', Decimal('0.99'))
# (1810, 'The God That Failed', Decimal('0.99'))
# (2318, 'Carnival Of Sorts', Decimal('0.99'))
# (2253, 'Se Liga', Decimal('0.99'))
# (3014, 'Desire', Decimal('0.99'))
# (2936, 'Acrobat', Decimal('0.99'))
# (959, 'King For A Day', Decimal('0.99'))
# (431, 'The Invisible Man', Decimal('0.99'))
# (2654, "Don't Stand so Close to Me", Decimal('0.99'))
# (2114, 'When The World Was Young', Decimal('0.99'))
# (1226, 'Can I Play With Madness', Decimal('0.99'))
# (2518, 'Pretty Noose', Decimal('0.99'))
# (911, 'Hey Hey', Decimal('0.99'))
# (462, "Valentino's", Decimal('0.99'))
# (3477, 'Amy Amy Amy (Outro)', Decimal('0.99'))
# (2561, 'Question!', Decimal('0.99'))
# (1123, 'Changes', Decimal('0.99'))
# (1317, 'Heaven Can Wait', Decimal('0.99'))
# (1272, '05 - Phantom of the Opera', Decimal('0.99'))
# (180, 'Body Count Anthem', Decimal('0.99'))
# (660, 'Carta Ao Tom 74', Decimal('0.99'))
# (2363, 'I Could Have Lied', Decimal('0.99'))
# (971, 'The Morning After', Decimal('0.99'))
# (2126, 'Slug', Decimal('0.99'))
# (941, 'Malpractice', Decimal('0.99'))
# (2761, 'Você Fugiu', Decimal('0.99'))
# (135, 'Super Terrorizer', Decimal('0.99'))
# (999, 'Still', Decimal('0.99'))
# (2624, 'Spirit Walker', Decimal('0.99'))
# (470, 'Longview', Decimal('0.99'))
# (780, "Maybe I'm A Leo", Decimal('0.99'))
# (500, 'Wherever You May Go', Decimal('0.99'))
# (1169, 'Garden of Eden', Decimal('0.99'))
# (2810, 'Caras Como Eu', Decimal('0.99'))
# (1236, 'Ghost Of The Navigator', Decimal('0.99'))
# (1928, 'Maria, Maria', Decimal('0.99'))
# (2769, 'Não Quero Dinheiro', Decimal('0.99'))
# (1353, 'The Wicker Man', Decimal('0.99'))
# (2768, 'Você', Decimal('0.99'))
# (2506, 'Nothing To Say', Decimal('0.99'))
# (2946, 'When I Look At The World', Decimal('0.99'))
# (1184, 'Estranged', Decimal('0.99'))
# (2792, 'A Melhor Forma', Decimal('0.99'))
# (1865, 'Better Than You', Decimal('0.99'))
# (843, 'Otay', Decimal('0.99'))
# (48, 'Not The Doctor', Decimal('0.99'))
# (2627, 'Wild Hearted Son', Decimal('0.99'))
# (3137, "Now You're Gone", Decimal('0.99'))
# (1192, "L'Arc En Ciel De Miles", Decimal('0.99'))
# (1661, 'Tea For One', Decimal('0.99'))
# (468, 'Maria', Decimal('0.99'))
# (3128, 'Samba Do Jato', Decimal('0.99'))
# (1436, 'Hooked Up', Decimal('0.99'))
# (171, 'Bowels Of The Devil', Decimal('0.99'))
# (2322, 'So Central Rain', Decimal('0.99'))
# (397, 'Linha Do Horizonte', Decimal('0.99'))
# (1281, 'Genghis Khan', Decimal('0.99'))
# (2381, "Can't Stop", Decimal('0.99'))
# (427, 'Who Wants To Live Forever', Decimal('0.99'))
# (807, 'Stormbringer', Decimal('0.99'))
# (3028, 'Zooropa', Decimal('0.99'))
# (2705, 'Walking Wounded', Decimal('0.99'))
# (686, 'Up Around The Bend', Decimal('0.99'))
# (321, 'Felicidade Urgente', Decimal('0.99'))
# (303, 'Falar A Verdade', Decimal('0.99'))
# (1819, 'Blitzkrieg', Decimal('0.99'))
# (402, 'Um Jantar Pra Dois', Decimal('0.99'))
# (1406, 'Futureal', Decimal('0.99'))
# (804, 'Fortuneteller', Decimal('0.99'))
# (472, 'Basket Case', Decimal('0.99'))
# (3456, "You Know I'm No Good", Decimal('0.99'))
# (3410, 'The Messiah: Behold, I Tell You a Mystery... The Trumpet Shall Sound', Decimal('0.99'))
# (2947, 'New York', Decimal('0.99'))
# (233, 'O Que Será (À Flor Da Terra)', Decimal('0.99'))
# (1934, 'Ponta de Areia', Decimal('0.99'))
# (2573, 'Sting Me', Decimal('0.99'))
# (2549, 'Piece Of Pie', Decimal('0.99'))
# (3110, 'Headspace', Decimal('0.99'))
# (1370, 'Run To The Hills', Decimal('0.99'))
# (1115, 'Tempo Rei', Decimal('0.99'))
# (93, 'Exploder', Decimal('0.99'))
# (2678, 'Gimmie Shelters', Decimal('0.99'))
# (3119, 'Tudo Na Mais Santa Paz', Decimal('0.99'))
# (1871, "Low Man's Lyric", Decimal('0.99'))
# (953, 'Star A.D.', Decimal('0.99'))
# (1097, 'Opachorô (Live)', Decimal('0.99'))
# (1374, 'The Evil That Men Do', Decimal('0.99'))
# (339, 'Communication Breakdown', Decimal('0.99'))
# (2320, 'Perfect Circle', Decimal('0.99'))
# (603, 'Bye Bye Blackbird', Decimal('0.99'))
# (2660, 'King Of Pain', Decimal('0.99'))
# (771, "Nobody's Home", Decimal('0.99'))
# (2786, 'O Pulso', Decimal('0.99'))
# (1888, 'Shoot Me Again', Decimal('0.99'))
# (2816, 'Toda Cor', Decimal('0.99'))
# (1099, 'A Novidade (Live)', Decimal('0.99'))
# (2732, 'Anyway, Anyhow, Anywhere', Decimal('0.99'))
# (621, 'Going Down / Highway Star', Decimal('0.99'))
# (1214, 'Prowler', Decimal('0.99'))
# (1394, 'The Prisoner', Decimal('0.99'))
# (2537, 'Travis Walk', Decimal('0.99'))
# (1382, 'Heaven Can Wait', Decimal('0.99'))
# (3485, 'Symphony No. 3 Op. 36 for Orchestra and Soprano "Symfonia Piesni Zalosnych" \\ Lento E Largo - Tranquillissimo', Decimal('0.99'))
# (1111, 'A Paz', Decimal('0.99'))
# (129, 'Solo-Panhandler', Decimal('0.99'))
# (2102, 'Mr. Crowley', Decimal('0.99'))
# (2387, 'On Mercury', Decimal('0.99'))
# (3356, 'Muita Bobeira', Decimal('0.99'))
# (795, 'Hey Cisco', Decimal('0.99'))
# (585, 'Entre E Ouça', Decimal('0.99'))
# (1181, 'Pretty Tied Up', Decimal('0.99'))
# (789, 'Sometimes I Feel Like Screaming', Decimal('0.99'))
# (3026, 'Surrender', Decimal('0.99'))
# (2957, 'Walk To The Water', Decimal('0.99'))
# (1172, 'Dead Horse', Decimal('0.99'))
# (2249, 'Rappers Reais', Decimal('0.99'))
# (1208, 'For the Greater Good of God', Decimal('0.99'))
# (162, 'Cornucopia', Decimal('0.99'))
# (1633, 'Ramble On', Decimal('0.99'))
# (2525, 'Rasul', Decimal('0.99'))
# (3053, "Hang 'Em High", Decimal('0.99'))
# (2767, 'Gostava Tanto De Você', Decimal('0.99'))
# (330, 'Levada do Amor (Ailoviu)', Decimal('0.99'))
# (237, 'Minha Historia', Decimal('0.99'))
# (1892, 'All Within My Hands', Decimal('0.99'))
# (1220, 'Run To The Hilss', Decimal('0.99'))
# (348, "I Can't Quit You Baby(2)", Decimal('0.99'))
# (3092, 'Neworld', Decimal('0.99'))
# (399, 'Abrir A Porta', Decimal('0.99'))
# (2750, 'You Better You Bet', Decimal('0.99'))
# (1299, 'Running Free', Decimal('0.99'))
# (1202, "These Colours Don't Run", Decimal('0.99'))
# (798, 'King Of Dreams', Decimal('0.99'))
# (1400, 'The Aftermath', Decimal('0.99'))
# (744, 'Mis Penas Lloraba Yo (Ao Vivo) Soy Gitano (Tangos)', Decimal('0.99'))
# (2696, 'Out Of Tears', Decimal('0.99'))
# (2612, 'Take The Power', Decimal('0.99'))
# (147, 'Blood In The Wall', Decimal('0.99'))
# (1809, 'Of Wolf And Man', Decimal('0.99'))
# (990, 'No Way Back', Decimal('0.99'))
# (480, 'Stuck With Me', Decimal('0.99'))
# (3365, 'Say Hello 2 Heaven', Decimal('0.99'))
# (989, 'In Your Honor', Decimal('0.99'))
# (678, 'Bad Moon Rising', Decimal('0.99'))
# (1168, 'The Garden', Decimal('0.99'))
# (3083, 'You Really Got Me', Decimal('0.99'))
# (1916, 'Coração De Estudante', Decimal('0.99'))
# (1176, 'Yesterdays', Decimal('0.99'))
# (198, 'When My Left Eye Jumps', Decimal('0.99'))
# (1290, 'The Trooper', Decimal('0.99'))
# (1089, 'Is This Love (Live)', Decimal('0.99'))
# (907, 'Promises', Decimal('0.99'))
# (3401, 'Show Me How to Live (Live at the Quart Festival)', Decimal('0.99'))
# (3465, "You Know I'm No Good (feat. Ghostface Killah)", Decimal('0.99'))
# (917, "Walkin' Blues", Decimal('0.99'))
# (834, 'When Love & Hate Collide', Decimal('0.99'))
# (831, 'Animal', Decimal('0.99'))
# (813, 'High Ball Shooter', Decimal('0.99'))
# (2132, 'Ito Okashi', Decimal('0.99'))
# (1335, 'Where Eagles Dare', Decimal('0.99'))
# (1245, 'Wildest Dreams', Decimal('0.99'))
# (225, "Sozinho (Caêdrum 'n' Bass)", Decimal('0.99'))
# (2927, 'Even Better Than The Real Thing', Decimal('0.99'))
# (1344, 'Aces High', Decimal('0.99'))
# (2699, 'Sweethearts Together', Decimal('0.99'))
# (2319, 'Radio Free Aurope', Decimal('0.99'))
# (395, 'Eu Vim Da Bahia - Live', Decimal('0.99'))
# (666, 'Coração do Agreste (Fafá de Belém)', Decimal('0.99'))
# (216, 'Esse Cara', Decimal('0.99'))
# (1655, 'Achilles Last Stand', Decimal('0.99'))
# (213, 'Saudosismo', Decimal('0.99'))
# (1430, 'Living In America', Decimal('0.99'))
# (1876, 'For Whom The Bell Tolls', Decimal('0.99'))
# (2508, 'Loud Love', Decimal('0.99'))
# (1904, 'The Duke', Decimal('0.99'))
# (1103, 'Lamento De Carnaval', Decimal('0.99'))
# (1244, 'The Thin Line Between Love & Hate', Decimal('0.99'))
# (3493, 'Metopes, Op. 29: Calypso', Decimal('0.99'))
# (221, 'Atrás Da Verd-E-Rosa Só Não Vai Quem Já Morreu', Decimal('0.99'))
# (2251, 'Hemp Family', Decimal('0.99'))
# (102, "Doesn't Remind Me", Decimal('0.99'))
# (2064, 'Caleidoscópio', Decimal('0.99'))
# (1553, "You've Got Another Thing Comin'", Decimal('0.99'))
# (594, 'Agora Que O Dia Acordou', Decimal('0.99'))
# (2090, 'Romance Ideal', Decimal('0.99'))
# (915, 'Layla', Decimal('0.99'))
# (111, 'Money', Decimal('0.99'))
# (3024, 'Two Hearts Beat As One', Decimal('0.99'))
# (1418, "Papa's Got A Brand New Bag Pt.1", Decimal('0.99'))
# (1884, 'Some Kind Of Monster', Decimal('0.99'))
# (1180, 'Breakdown', Decimal('0.99'))
# (492, "Don't You Cry", Decimal('0.99'))
# (2375, 'By The Way', Decimal('0.99'))
# (2120, 'Walking Into Clarksdale', Decimal('0.99'))
# (1139, 'Give Me Novacaine', Decimal('0.99'))
# (1667, 'No Quarter', Decimal('0.99'))
# (925, 'Last Cup Of Sorrow', Decimal('0.99'))
# (1080, 'Assum Preto', Decimal('0.99'))
# (656, 'Berimbau', Decimal('0.99'))
# (2669, 'Get Off Of My Cloud', Decimal('0.99'))
# (208, 'Terra', Decimal('0.99'))
# (2512, 'Outshined', Decimal('0.99'))
# (3022, 'Drowning Man', Decimal('0.99'))
# (648, 'Onde Anda Você', Decimal('0.99'))
# (1026, 'My Hero', Decimal('0.99'))
# (995, 'Free Me', Decimal('0.99'))
# (1188, 'Colibri', Decimal('0.99'))
# (211, 'Bem Devagar', Decimal('0.99'))
# (3489, 'Symphony No. 2: III. Allegro vivace', Decimal('0.99'))
# (1625, "I Can't Quit You Baby", Decimal('0.99'))
# (2949, 'The Three Sunrises', Decimal('0.99'))
# (1853, 'Battery', Decimal('0.99'))
# (2714, 'Heaven Coming Down', Decimal('0.99'))
# (912, 'Tears In Heaven', Decimal('0.99'))
# (2771, 'A Festa Do Santo Reis', Decimal('0.99'))
# (753, 'You Keep On Moving', Decimal('0.99'))
# (652, 'Formosa', Decimal('0.99'))
# (2723, 'Gyroscope', Decimal('0.99'))
# (394, 'Tanto Tempo', Decimal('0.99'))
# (1898, 'Harvester Of Sorrow', Decimal('0.99'))
# (1362, 'Dream Of Mirrors', Decimal('0.99'))
# (867, 'Açai', Decimal('0.99'))
# (858, 'Esquinas', Decimal('0.99'))
# (2606, 'Know Your Rights', Decimal('0.99'))
# (1691, 'Indios', Decimal('0.99'))
# (2108, 'Children Of The Grave', Decimal('0.99'))
# (670, 'Romaria (Renato Teixeira)', Decimal('0.99'))
# (576, 'Maria Maria', Decimal('0.99'))
# (3437, 'Piano Sonata No. 14 in C Sharp Minor, Op. 27, No. 2, "Moonlight": I. Adagio sostenuto', Decimal('0.99'))
# (849, 'Baltimore, DC', Decimal('0.99'))
# (3464, 'He Can Only Hold Her', Decimal('0.99'))
# (929, 'Ashes To Ashes', Decimal('0.99'))
# (1366, 'Iron Maiden', Decimal('0.99'))
# (1811, 'My Friend Of Misery', Decimal('0.99'))
# (3020, "New Year's Day", Decimal('0.99'))
# (1175, '14 Years', Decimal('0.99'))
# (1673, 'Música De Trabalho', Decimal('0.99'))
# (2642, 'Twentienth Century Fox', Decimal('0.99'))
# (1263, 'Chains Of Misery', Decimal('0.99'))
# (1872, 'Attitude', Decimal('0.99'))
# (189, 'Jerusalem', Decimal('0.99'))
# (876, 'Um Amor Puro', Decimal('0.99'))
# (117, "Rock 'N' Roll Music", Decimal('0.99'))
# (3146, 'Faixa Amarela', Decimal('0.99'))
# (1308, 'From Here To Eternity', Decimal('0.99'))
# (1166, "Double Talkin' Jive", Decimal('0.99'))
# (658, 'Pot-Pourri N.º 2', Decimal('0.99'))
# (1637, 'Friends', Decimal('0.99'))
# (120, 'Carol', Decimal('0.99'))
# (1649, 'Ten Years Gone', Decimal('0.99'))
# (2357, 'Rock Das Aranhas (Ao Vivo) (Live)', Decimal('0.99'))
# (2953, 'Bass Trap', Decimal('0.99'))
# (57, "It Ain't Like That", Decimal('0.99'))
# (3071, 'Panama', Decimal('0.99'))
# ------------------------------
# (3200, 'Gay Witch Hunt', Decimal('3.98)
# (3428, 'Branch Closing', Decimal('1.99)
# (3204, 'The Initiation', Decimal('1.99)
# (3182, 'Halloween', Decimal('1.99)
# (3208, 'The Convict', Decimal('1.99)
# (3230, 'Lost Planet of the Gods, Pt. 2', Decimal('1.99)
# (2837, 'Crossroads, Pt. 1', Decimal('1.99)
# (2822, 'Exodus, Pt. 2', Decimal('1.99)
# (3222, 'The Job', Decimal('1.99)
# (2909, 'Catch-22', Decimal('1.99)
# (3201, 'The Convention', Decimal('1.99)
# (2855, 'Company Man', Decimal('1.99)
# (2873, 'House of the Rising Sun', Decimal('1.99)
# (3210, 'Back from Vacation', Decimal('1.99)
# (3209, 'A Benihana Christmas, Pts. 1 & 2', Decimal('1.99)
# (3173, 'Diversity Day', Decimal('1.99)
# (3214, 'Phyllis's Wedding', Decimal('1.99)
# (2864, 'Orientation', Decimal('1.99)
# (3191, 'The Carpet', Decimal('1.99)
# (2918, '"?"', Decimal('1.99)
# (2882, 'Lost Survival Guide', Decimal('1.99)
# (3226, 'Battlestar Galactica, Pt. 1', Decimal('1.99)
# (3218, 'Safety Training', Decimal('1.99)
# (3206, 'Branch Closing', Decimal('1.99)
# (2828, 'The Passage', Decimal('1.99)
# (3347, 'Meet Kevin Johnson', Decimal('1.99)
# (3212, 'Producer's Cut: The Return', Decimal('1.99)
# (2900, 'Exposé', Decimal('1.99)
# (3238, 'The Living Legend, Pt. 2', Decimal('1.99)
# (3234, 'The Gun On Ice Planet Zero, Pt. 2', Decimal('1.99)
# (2891, 'Enter 77', Decimal('1.99)
# (2846, 'Seven Minutes to Midnight', Decimal('1.99)
# (3202, 'The Coup', Decimal('1.99)
# (2636, 'Sun King', Decimal('1.98)
# (2618, 'Speed Of Light', Decimal('1.98)
# (2759, 'Música No Ar', Decimal('1.98)
# (2600, 'Train In Vain', Decimal('1.98)
# (3455, 'Rehab', Decimal('1.98)
# (207, 'Meditação', Decimal('1.98)
# (2945, 'Peace On Earth', Decimal('1.98)
# (241, 'Geni E O Zepelim', Decimal('0.99)
# (1172, 'Dead Horse', Decimal('0.99)
# (321, 'Felicidade Urgente', Decimal('0.99)
# (678, 'Bad Moon Rising', Decimal('0.99)
# (2108, 'Children Of The Grave', Decimal('0.99)
# (2543, 'Sex Type Thing', Decimal('0.99)
# (1176, 'Yesterdays', Decimal('0.99)
# (1637, 'Friends', Decimal('0.99)
# (1035, 'New York, New York', Decimal('0.99)
# (1898, 'Harvester Of Sorrow', Decimal('0.99)
# (603, 'Bye Bye Blackbird', Decimal('0.99)
# (594, 'Agora Que O Dia Acordou', Decimal('0.99)
# (1807, 'Through The Never', Decimal('0.99)
# (1811, 'My Friend Of Misery', Decimal('0.99)
# (2699, 'Sweethearts Together', Decimal('0.99)
# (1181, 'Pretty Tied Up', Decimal('0.99)
# (977, 'Xote Dos Milagres', Decimal('0.99)
# (1062, 'Zambação', Decimal('0.99)
# (3110, 'Headspace', Decimal('0.99)
# (1430, 'Living In America', Decimal('0.99)
# (658, 'Pot-Pourri N.º 2', Decimal('0.99)
# (941, 'Malpractice', Decimal('0.99)
# (2936, 'Acrobat', Decimal('0.99)
# (1876, 'For Whom The Bell Tolls', Decimal('0.99)
# (885, 'Fascinação', Decimal('0.99)
# (2387, 'On Mercury', Decimal('0.99)
# (2732, 'Anyway, Anyhow, Anywhere', Decimal('0.99)
# (138, 'Bored To Tears', Decimal('0.99)
# (1819, 'Blitzkrieg', Decimal('0.99)
# (431, 'The Invisible Man', Decimal('0.99)
# (476, 'Geek Stink Breath', Decimal('0.99)
# (1044, 'My Kind Of Town', Decimal('0.99)
# (3137, 'Now You're Gone', Decimal('0.99)
# (2508, 'Loud Love', Decimal('0.99)
# (3065, 'Ain't Talkin' 'bout Love', Decimal('0.99)
# (1382, 'Heaven Can Wait', Decimal('0.99)
# (1184, 'Estranged', Decimal('0.99)
# (411, 'Turn The Page', Decimal('0.99)
# (3485, 'Symphony No. 3 Op. 36 for Orchestra and Soprano "Symfonia Piesni Zalosnych" \ Lento E Largo - Tranquillissimo', Decimal('0.99)
# (1133, 'American Idiot', Decimal('0.99)
# (1366, 'Iron Maiden', Decimal('0.99)
# (3101, 'Primary', Decimal('0.99)
# (858, 'Esquinas', Decimal('0.99)
# (2760, 'Salve Nossa Senhora', Decimal('0.99)
# (1008, 'Razor', Decimal('0.99)
# (1163, 'You Ain't the First', Decimal('0.99)
# (1281, 'Genghis Khan', Decimal('0.99)
# (1263, 'Chains Of Misery', Decimal('0.99)
# (3020, 'New Year's Day', Decimal('0.99)
# (245, 'Construção / Deus Lhe Pague', Decimal('0.99)
# (2780, 'Formigueiro', Decimal('0.99)
# (2318, 'Carnival Of Sorts', Decimal('0.99)
# (1335, 'Where Eagles Dare', Decimal('0.99)
# (2946, 'When I Look At The World', Decimal('0.99)
# (3473, 'Take the Box', Decimal('0.99)
# (909, 'Signe', Decimal('0.99)
# (2761, 'Você Fugiu', Decimal('0.99)
# (2249, 'Rappers Reais', Decimal('0.99)
# (198, 'When My Left Eye Jumps', Decimal('0.99)
# (2955, 'Everlasting Love', Decimal('0.99)
# (2065, 'Trac Trac', Decimal('0.99)
# (1250, 'Gates Of Tomorrow', Decimal('0.99)
# (312, 'Eu Também Quero Beijar', Decimal('0.99)
# (1123, 'Changes', Decimal('0.99)
# (1378, 'Only the Good Die Young', Decimal('0.99)
# (221, 'Atrás Da Verd-E-Rosa Só Não Vai Quem Já Morreu', Decimal('0.99)
# (1829, 'Hit The Lights', Decimal('0.99)
# (789, 'Sometimes I Feel Like Screaming', Decimal('0.99)
# (3481, 'A Midsummer Night's Dream, Op.61 Incidental Music: No.7 Notturno', Decimal('0.99)
# (415, 'Astronomy', Decimal('0.99)
# (621, 'Going Down / Highway Star', Decimal('0.99)
# (1643, 'That's The Way', Decimal('0.99)
# (907, 'Promises', Decimal('0.99)
# (3146, 'Faixa Amarela', Decimal('0.99)
# (1809, 'Of Wolf And Man', Decimal('0.99)
# (1244, 'The Thin Line Between Love & Hate', Decimal('0.99)
# (2804, 'Lugar Nenhum', Decimal('0.99)
# (3465, 'You Know I'm No Good (feat. Ghostface Killah)', Decimal('0.99)
# (1080, 'Assum Preto', Decimal('0.99)
# (1089, 'Is This Love (Live)', Decimal('0.99)
# (111, 'Money', Decimal('0.99)
# (913, 'Lonely Stranger', Decimal('0.99)
# (2324, 'Pretty Persuasion', Decimal('0.99)
# (2514, 'Spoonman', Decimal('0.99)
# (1424, 'Hey America', Decimal('0.99)
# (1629, 'The Lemon Song', Decimal('0.99)
# (795, 'Hey Cisco', Decimal('0.99)
# (1157, 'Rocket Queen', Decimal('0.99)
# (2765, 'Réu Confesso', Decimal('0.99)
# (3356, 'Muita Bobeira', Decimal('0.99)
# (500, 'Wherever You May Go', Decimal('0.99)
# (1815, 'The Wait', Decimal('0.99)
# (981, 'Zeca Violeiro', Decimal('0.99)
# (735, 'Metrô. Linha 743', Decimal('0.99)
# (2567, 'Duende', Decimal('0.99)
# (2678, 'Gimmie Shelters', Decimal('0.99)
# (1412, 'Don't Look To The Eyes Of A Stranger', Decimal('0.99)
# (1053, 'Bad, Bad Leroy Brown', Decimal('0.99)
# (2690, 'Love Is Strong', Decimal('0.99)
# (1168, 'The Garden', Decimal('0.99)
# (108, 'Dandelion', Decimal('0.99)
# (807, 'Stormbringer', Decimal('0.99)
# (585, 'Entre E Ouça', Decimal('0.99)
# (2949, 'The Three Sunrises', Decimal('0.99)
# (30, 'Amazing', Decimal('0.99)
# (1101, 'De Ouro E Marfim (Live)', Decimal('0.99)
# (1406, 'Futureal', Decimal('0.99)
# (831, 'Animal', Decimal('0.99)
# (395, 'Eu Vim Da Bahia - Live', Decimal('0.99)
# (540, 'Posso Perder Minha Mulher, Minha Mãe, Desde Que Eu Tenha O Rock And Roll', Decimal('0.99)
# (2504, 'Real Love', Decimal('0.99)
# (876, 'Um Amor Puro', Decimal('0.99)
# (2669, 'Get Off Of My Cloud', Decimal('0.99)
# (2126, 'Slug', Decimal('0.99)
# (1127, 'I Fucking Hate You', Decimal('0.99)
# (2518, 'Pretty Noose', Decimal('0.99)
# (3041, 'Homely Girl', Decimal('0.99)
# (1394, 'The Prisoner', Decimal('0.99)
# (1196, 'Millenium', Decimal('0.99)
# (971, 'The Morning After', Decimal('0.99)
# (394, 'Tanto Tempo', Decimal('0.99)
# (2771, 'A Festa Do Santo Reis', Decimal('0.99)
# (1026, 'My Hero', Decimal('0.99)
# (849, 'Baltimore, DC', Decimal('0.99)
# (2786, 'O Pulso', Decimal('0.99)
# (2591, 'White Riot', Decimal('0.99)
# (1649, 'Ten Years Gone', Decimal('0.99)
# (2672, 'Paint It Black', Decimal('0.99)
# (3026, 'Surrender', Decimal('0.99)
# (1103, 'Lamento De Carnaval', Decimal('0.99)
# (2927, 'Even Better Than The Real Thing', Decimal('0.99)
# (2627, 'Wild Hearted Son', Decimal('0.99)
# (2609, 'War (The Process)', Decimal('0.99)
# (1139, 'Give Me Novacaine', Decimal('0.99)
# (1362, 'Dream Of Mirrors', Decimal('0.99)
# (144, 'Heart Of Gold', Decimal('0.99)
# (612, 'Nefertiti', Decimal('0.99)
# (135, 'Super Terrorizer', Decimal('0.99)
# (959, 'King For A Day', Decimal('0.99)
# (3015, 'When Love Comes To Town', Decimal('0.99)
# (66, 'Por Causa De Você', Decimal('0.99)
# (2381, 'Can't Stop', Decimal('0.99)
# (126, 'Moon germs', Decimal('0.99)
# (1220, 'Run To The Hilss', Decimal('0.99)
# (48, 'Not The Doctor', Decimal('0.99)
# (180, 'Body Count Anthem', Decimal('0.99)
# (1169, 'Garden of Eden', Decimal('0.99)
# (1810, 'The God That Failed', Decimal('0.99)
# (2954, 'Dancing Barefoot', Decimal('0.99)
# (2096, 'Flying High Again', Decimal('0.99)
# (1621, 'Dazed and Confused', Decimal('0.99)
# (2642, 'Twentienth Century Fox', Decimal('0.99)
# (2768, 'Você', Decimal('0.99)
# (2957, 'Walk To The Water', Decimal('0.99)
# (903, 'Lay Down Sally', Decimal('0.99)
# (726, 'Palavras Ao Vento', Decimal('0.99)
# (1226, 'Can I Play With Madness', Decimal('0.99)
# (2660, 'King Of Pain', Decimal('0.99)
# (405, 'Santo Antonio', Decimal('0.99)
# (929, 'Ashes To Ashes', Decimal('0.99)
# (3014, 'Desire', Decimal('0.99)
# (1884, 'Some Kind Of Monster', Decimal('0.99)
# (674, 'Preciso Apender a Viver Só (Maysa)', Decimal('0.99)
# (3463, 'Some Unholy War', Decimal('0.99)
# (2351, 'Todo Mundo Explica', Decimal('0.99)
# (2645, 'Back Door Man', Decimal('0.99)
# (3047, 'Bring Me Your Cup', Decimal('0.99)
# (3022, 'Drowning Man', Decimal('0.99)
# (1166, 'Double Talkin' Jive', Decimal('0.99)
# (229, 'Samba De Orly', Decimal('0.99)
# (1946, 'Fast And Loose', Decimal('0.99)
# (1299, 'Running Free', Decimal('0.99)
# (1214, 'Prowler', Decimal('0.99)
# (3392, 'Until We Fall', Decimal('0.99)
# (1916, 'Coração De Estudante', Decimal('0.99)
# (933, 'Home Sick Home', Decimal('0.99)
# (660, 'Carta Ao Tom 74', Decimal('0.99)
# (399, 'Abrir A Porta', Decimal('0.99)
# (639, 'Don't Take Your Love From Me', Decimal('0.99)
# (2687, 'Thief In The Night', Decimal('0.99)
# (366, 'Camisa Verde 2001', Decimal('0.99)
# (744, 'Mis Penas Lloraba Yo (Ao Vivo) Soy Gitano (Tangos)', Decimal('0.99)
# (496, 'Living On Love', Decimal('0.99)
# (1679, 'Dezesseis', Decimal('0.99)
# (2773, 'Padre Cícero', Decimal('0.99)
# (915, 'Layla', Decimal('0.99)
# (1633, 'Ramble On', Decimal('0.99)
# (1272, '05 - Phantom of the Opera', Decimal('0.99)
# (1940, 'Norwegian Wood', Decimal('0.99)
# (921, 'Old Love', Decimal('0.99)
# (666, 'Coração do Agreste (Fafá de Belém)', Decimal('0.99)
# (3457, 'Me & Mr. Jones', Decimal('0.99)
# (652, 'Formosa', Decimal('0.99)
# (2763, 'Compadre', Decimal('0.99)
# (3410, 'The Messiah: Behold, I Tell You a Mystery... The Trumpet Shall Sound', Decimal('0.99)
# (2654, 'Don't Stand so Close to Me', Decimal('0.99)
# (147, 'Blood In The Wall', Decimal('0.99)
# (213, 'Saudosismo', Decimal('0.99)
# (3419, 'Requiem, Op.48: 4. Pie Jesu', Decimal('0.99)
# (3374, 'All Night Thing', Decimal('0.99)
# (558, 'Viradouro', Decimal('0.99)
# (656, 'Berimbau', Decimal('0.99)
# (911, 'Hey Hey', Decimal('0.99)
# (393, 'Tarde Em Itapoã', Decimal('0.99)
# (3446, 'Symphonie Fantastique, Op. 14: V. Songe d'une nuit du sabbat', Decimal('0.99)
# (567, 'Tradição', Decimal('0.99)
# (2705, 'Walking Wounded', Decimal('0.99)
# (657, 'Deixa', Decimal('0.99)
# (217, 'Mel', Decimal('0.99)
# (867, 'Açai', Decimal('0.99)
# (39, 'You Oughta Know', Decimal('0.99)
# (813, 'High Ball Shooter', Decimal('0.99)
# (102, 'Doesn't Remind Me', Decimal('0.99)
# (3461, 'Tears Dry On Their Own', Decimal('0.99)
# (468, 'Maria', Decimal('0.99)
# (1370, 'Run To The Hills', Decimal('0.99)
# (2132, 'Ito Okashi', Decimal('0.99)
# (2363, 'I Could Have Lied', Decimal('0.99)
# (2512, 'Outshined', Decimal('0.99)
# (3464, 'He Can Only Hold Her', Decimal('0.99)
# (215, 'Sozinho', Decimal('0.99)
# (1871, 'Low Man's Lyric', Decimal('0.99)
# (3059, 'Little Guitars (Intro)', Decimal('0.99)
# (2594, 'Clash City Rockers', Decimal('0.99)
# (462, 'Valentino's', Decimal('0.99)
# (464, 'As We Sleep', Decimal('0.99)
# (822, 'A Twist In The Tail', Decimal('0.99)
# (484, 'Nice Guys Finish Last', Decimal('0.99)
# (1892, 'All Within My Hands', Decimal('0.99)
# (2723, 'Gyroscope', Decimal('0.99)
# (2253, 'Se Liga', Decimal('0.99)
# (912, 'Tears In Heaven', Decimal('0.99)
# (3092, 'Neworld', Decimal('0.99)
# (1625, 'I Can't Quit You Baby', Decimal('0.99)
# (1317, 'Heaven Can Wait', Decimal('0.99)
# (2951, 'Sweetest Thing', Decimal('0.99)
# (209, 'Eclipse Oculto', Decimal('0.99)
# (463, 'Believe', Decimal('0.99)
# (3119, 'Tudo Na Mais Santa Paz', Decimal('0.99)
# (294, 'Pensamento', Decimal('0.99)
# (965, 'Epic', Decimal('0.99)
# (1170, 'Don't Damn Me', Decimal('0.99)
# (120, 'Carol', Decimal('0.99)
# (995, 'Free Me', Decimal('0.99)
# (384, 'Mistério da Raça', Decimal('0.99)
# (1617, 'When The Levee Breaks', Decimal('0.99)
# (93, 'Exploder', Decimal('0.99)
# (84, 'Welcome Home (Sanitarium)', Decimal('0.99)
# (2741, 'Pinball Wizard', Decimal('0.99)
# (1803, 'Holier Than Thou', Decimal('0.99)
# (357, 'Advance Romance', Decimal('0.99)
# (1188, 'Colibri', Decimal('0.99)
# (1374, 'The Evil That Men Do', Decimal('0.99)
# (57, 'It Ain't Like That', Decimal('0.99)
# (2345, 'O Dia Em Que A Terra Parou', Decimal('0.99)
# (75, 'O Boto (Bôto)', Decimal('0.99)
# (3071, 'Panama', Decimal('0.99)
# (1236, 'Ghost Of The Navigator', Decimal('0.99)
# (654, 'Minha Namorada', Decimal('0.99)
# (816, 'The Battle Rages On', Decimal('0.99)
# (2663, 'Message in a Bottle (new classic rock mix)', Decimal('0.99)
# (285, 'Soldado Da Paz', Decimal('0.99)
# (834, 'When Love & Hate Collide', Decimal('0.99)
# (3083, 'You Really Got Me', Decimal('0.99)
# (1017, 'Overdrive', Decimal('0.99)
# (3365, 'Say Hello 2 Heaven', Decimal('0.99)
# (989, 'In Your Honor', Decimal('0.99)
# (2320, 'Perfect Circle', Decimal('0.99)
# (153, 'Evil Woman', Decimal('0.99)
# (1655, 'Achilles Last Stand', Decimal('0.99)
# (3018, 'Sunday Bloody Sunday', Decimal('0.99)
# (753, 'You Keep On Moving', Decimal('0.99)
# (2624, 'Spirit Walker', Decimal('0.99)
# (3024, 'Two Hearts Beat As One', Decimal('0.99)
# (2681, 'Corinna', Decimal('0.99)
# (2505, '[Untitled]', Decimal('0.99)
# (630, 'Boogie Blues', Decimal('0.99)
# (348, 'I Can't Quit You Baby(2)', Decimal('0.99)
# (2102, 'Mr. Crowley', Decimal('0.99)
# (1238, 'Blood Brothers', Decimal('0.99)
# (1111, 'A Paz', Decimal('0.99)
# (2696, 'Out Of Tears', Decimal('0.99)
# (189, 'Jerusalem', Decimal('0.99)
# (1098, 'Copacabana (Live)', Decimal('0.99)
# (2714, 'Heaven Coming Down', Decimal('0.99)
# (480, 'Stuck With Me', Decimal('0.99)
# (1847, 'Poor Twisted Me', Decimal('0.99)
# (2792, 'A Melhor Forma', Decimal('0.99)
# (219, 'Odara', Decimal('0.99)
# (233, 'O Que Será (À Flor Da Terra)', Decimal('0.99)
# (2549, 'Piece Of Pie', Decimal('0.99)
# (1418, 'Papa's Got A Brand New Bag Pt.1', Decimal('0.99)
# (1661, 'Tea For One', Decimal('0.99)
# (2798, 'Homem Primata', Decimal('0.99)
# (762, 'No No No', Decimal('0.99)
# (1872, 'Attitude', Decimal('0.99)
# (1685, 'O Livro Dos Dias', Decimal('0.99)
# (407, 'Só Tinha De Ser Com Você', Decimal('0.99)
# (1691, 'Indios', Decimal('0.99)
# (2555, 'B.Y.O.B.', Decimal('0.99)
# (208, 'Terra', Decimal('0.99)
# (1865, 'Better Than You', Decimal('0.99)
# (3077, 'Can't Stop Loving You', Decimal('0.99)
# (2606, 'Know Your Rights', Decimal('0.99)
# (947, 'Midnight Cowboy', Decimal('0.99)
# (1115, 'Tempo Rei', Decimal('0.99)
# (1192, 'L'Arc En Ciel De Miles', Decimal('0.99)
# (1673, 'Música De Trabalho', Decimal('0.99)
# (2531, 'End Of Romanticism', Decimal('0.99)
# (917, 'Walkin' Blues', Decimal('0.99)
# (1880, 'Creeping Death', Decimal('0.99)
# (488, 'Macy's Day Parade', Decimal('0.99)
# (1904, 'The Duke', Decimal('0.99)
# (771, 'Nobody's Home', Decimal('0.99)
# (303, 'Falar A Verdade', Decimal('0.99)
# (798, 'King Of Dreams', Decimal('0.99)
# (990, 'No Way Back', Decimal('0.99)
# (2525, 'Rasul', Decimal('0.99)
# (670, 'Romaria (Renato Teixeira)', Decimal('0.99)
# (1180, 'Breakdown', Decimal('0.99)
# (2953, 'Bass Trap', Decimal('0.99)
# (3456, 'You Know I'm No Good', Decimal('0.99)
# (2947, 'New York', Decimal('0.99)
# (1099, 'A Novidade (Live)', Decimal('0.99)
# (1151, 'Paradise City', Decimal('0.99)
# (1175, '14 Years', Decimal('0.99)
# (3493, 'Metopes, Op. 29: Calypso', Decimal('0.99)
# (403, 'Bumbo Da Mangueira', Decimal('0.99)
# (1290, 'The Trooper', Decimal('0.99)
# (1107, 'Refazenda', Decimal('0.99)
# (2767, 'Gostava Tanto De Você', Decimal('0.99)
# (2561, 'Question!', Decimal('0.99)
# (682, 'Down On The Corner', Decimal('0.99)
# (2810, 'Caras Como Eu', Decimal('0.99)
# (1254, 'Age Of Innocence', Decimal('0.99)
# (1835, 'Phantom Lord', Decimal('0.99)
# (2063, 'Nebulosa Do Amor', Decimal('0.99)
# (1859, 'Orion', Decimal('0.99)
# (2369, 'Naked In The Rain', Decimal('0.99)
# (330, 'Levada do Amor (Ailoviu)', Decimal('0.99)
# (1667, 'No Quarter', Decimal('0.99)
# (2816, 'Toda Cor', Decimal('0.99)
# (1071, 'Divirta-Se (Saindo Da Sua)', Decimal('0.99)
# (1823, 'So What', Decimal('0.99)
# (1353, 'The Wicker Man', Decimal('0.99)
# (1928, 'Maria, Maria', Decimal('0.99)
# (1910, 'Lament', Decimal('0.99)
# (1553, 'You've Got Another Thing Comin'', Decimal('0.99)
# (1202, 'These Colours Don't Run', Decimal('0.99)
# (2612, 'Take The Power', Decimal('0.99)
# (423, 'I Want To Break Free', Decimal('0.99)
# (2319, 'Radio Free Aurope', Decimal('0.99)
# (1326, 'Holy Smoke', Decimal('0.99)
# (1877, 'Fade To Black', Decimal('0.99)
# (162, 'Cornucopia', Decimal('0.99)
# (648, 'Onde Anda Você', Decimal('0.99)
# (3489, 'Symphony No. 2: III. Allegro vivace', Decimal('0.99)
# (1934, 'Ponta de Areia', Decimal('0.99)
# (225, 'Sozinho (Caêdrum 'n' Bass)', Decimal('0.99)
# (3016, 'Angel Of Harlem', Decimal('0.99)
# (576, 'Maria Maria', Decimal('0.99)
# (474, 'She', Decimal('0.99)
# (925, 'Last Cup Of Sorrow', Decimal('0.99)
# (2255, 'Another One Bites The Dust', Decimal('0.99)
# (2064, 'Caleidoscópio', Decimal('0.99)
# (1388, 'Children of the Damned', Decimal('0.99)
# (3467, 'Intro / Stronger Than Me', Decimal('0.99)
# (3053, 'Hang 'Em High', Decimal('0.99)
# (662, 'Pela Luz dos Olhos Teus (Miúcha e Tom Jobim)', Decimal('0.99)
# (1344, 'Aces High', Decimal('0.99)
# (1145, 'Whatsername', Decimal('0.99)
# (216, 'Esse Cara', Decimal('0.99)
# (2251, 'Hemp Family', Decimal('0.99)
# (2506, 'Nothing To Say', Decimal('0.99)
# (1808, 'Nothing Else Matters', Decimal('0.99)
# (3164, 'Verdade', Decimal('0.99)
# (1400, 'The Aftermath', Decimal('0.99)
# (2114, 'When The World Was Young', Decimal('0.99)
# (99, 'Your Time Has Come', Decimal('0.99)
# (402, 'Um Jantar Pra Dois', Decimal('0.99)
# (2630, 'Edie (Ciao Baby)', Decimal('0.99)
# (2250, 'Nega Do Cabelo Duro', Decimal('0.99)
# (3383, 'Scar On the Sky', Decimal('0.99)
# (470, 'Longview', Decimal('0.99)
# (2769, 'Não Quero Dinheiro', Decimal('0.99)
# (492, 'Don't You Cry', Decimal('0.99)
# (1308, 'From Here To Eternity', Decimal('0.99)
# (3401, 'Show Me How to Live (Live at the Quart Festival)', Decimal('0.99)
# (397, 'Linha Do Horizonte', Decimal('0.99)
# (3035, 'The First Time', Decimal('0.99)
# (843, 'Otay', Decimal('0.99)
# (780, 'Maybe I'm A Leo', Decimal('0.99)
# (3459, 'Back to Black', Decimal('0.99)
# (466, 'J Squared', Decimal('0.99)
# (1119, 'Toda Menina Baiana', Decimal('0.99)
# (2357, 'Rock Das Aranhas (Ao Vivo) (Live)', Decimal('0.99)
# (2375, 'By The Way', Decimal('0.99)
# (3155, 'Sem Essa de Malandro Agulha', Decimal('0.99)
# (2120, 'Walking Into Clarksdale', Decimal('0.99)
# (840, 'Hysteria', Decimal('0.99)
# (2339, 'Puteiro Em João Pessoa', Decimal('0.99)
# (3128, 'Samba Do Jato', Decimal('0.99)
# (2651, 'Can't Stand Losing You', Decimal('0.99)
# (3477, 'Amy Amy Amy (Outro)', Decimal('0.99)
# (3028, 'Zooropa', Decimal('0.99)
# (1922, 'Menestrel Das Alagoas', Decimal('0.99)
# (3437, 'Piano Sonata No. 14 in C Sharp Minor, Op. 27, No. 2, "Moonlight": I. Adagio sostenuto', Decimal('0.99)
# (2537, 'Travis Walk', Decimal('0.99)
# (825, 'One Man's Meat', Decimal('0.99)
# (2322, 'So Central Rain', Decimal('0.99)
# (419, 'A Kind Of Magic', Decimal('0.99)
# (117, 'Rock 'N' Roll Music', Decimal('0.99)
# (894, 'Sunshine Of Your Love', Decimal('0.99)
# (804, 'Fortuneteller', Decimal('0.99)
# (2959, 'Hallelujah Here She Comes', Decimal('0.99)
# (2573, 'Sting Me', Decimal('0.99)
# (1208, 'For the Greater Good of God', Decimal('0.99)
# (2510, 'Get On The Snake', Decimal('0.99)
# (1841, 'The House Jack Built', Decimal('0.99)
# (211, 'Bem Devagar', Decimal('0.99)
# (375, 'Mas Que Nada', Decimal('0.99)
# (999, 'Still', Decimal('0.99)
# (549, 'You Fool No One', Decimal('0.99)
# (3469, 'F**k Me Pumps', Decimal('0.99)
# (1888, 'Shoot Me Again', Decimal('0.99)
# (937, 'Midlife Crisis', Decimal('0.99)
# (1436, 'Hooked Up', Decimal('0.99)
# (472, 'Basket Case', Decimal('0.99)
# (686, 'Up Around The Bend', Decimal('0.99)
# (171, 'Bowels Of The Devil', Decimal('0.99)
# (2084, 'O Beco', Decimal('0.99)
# (1245, 'Wildest Dreams', Decimal('0.99)
# (983, 'Principiando/Decolagem', Decimal('0.99)
# (401, 'Momentos Que Marcam', Decimal('0.99)
# (2516, 'Black Hole Sun', Decimal('0.99)
# (2090, 'Romance Ideal', Decimal('0.99)
# (2582, 'Black Moon Creeping', Decimal('0.99)
# (1097, 'Opachorô (Live)', Decimal('0.99)
# (129, 'Solo-Panhandler', Decimal('0.99)
# (2750, 'You Better You Bet', Decimal('0.99)
# (339, 'Communication Breakdown', Decimal('0.99)
# (953, 'Star A.D.', Decimal('0.99)
# (427, 'Who Wants To Live Forever', Decimal('0.99)
# (237, 'Minha Historia', Decimal('0.99)
# (1232, 'Heaven Can Wait', Decimal('0.99)
# (1853, 'Battery', Decimal('0.99)

# %%
import psycopg2
# Duracion promedio de las canciones de un album
# Conexión usando variables de entorno
conn = get_postgres_connection()
cur = conn.cursor()

# Ejecutar una consulta
cur.execute("""
    SELECT AVG(milliseconds / 1000) AS avg_duration
    FROM track
    WHERE album_id = 1;
""")
rows = cur.fetchall()

# Mostrar resultados
for row in rows:
    print(row)



# Cerrar conexiones
cur.close()
conn.close()

print("------------------------------")

album_id = 1

pipeline = [
    {"$match": {"album_id": album_id}},
    {"$unwind": "$tracks"},
    {"$group": {
        "_id": "$album_id",
        "album_title": {"$first": "$title"},
        "average_duration_ms": {"$avg": "$tracks.milliseconds"}
    }},
    {"$project": {
        "_id": 0,
        "album_id": "$_id",
        "album_title": 1,
        "average_duration_ms": 1,
        "average_duration_seconds": {"$divide": ["$average_duration_ms", 1000]}
    }}
]

result = db.albums.aggregate(pipeline)
# result = db.albums.find({'album_id': album_id},{'tracks.milliseconds': 1 , '_id': 0})
# for doc in result:
#   print(doc)

for doc in result:
    print(f"Álbum: {doc['album_title']} (ID: {doc['album_id']})")
    print(f"Duración promedio: {doc['average_duration_ms']} ms ({doc['average_duration_seconds']} segundos)")
# Out:
# (Decimal('239.4000000000000000'),)
# ------------------------------
# Álbum: For Those About To Rock We Salute You (ID: 1)
# Duración promedio: 240041.5 ms (240.0415 segundos)

# %%
import psycopg2
# Mostrar que empleado representa a cada cliente
# Conexión usando variables de entorno
conn = get_postgres_connection()
cur = conn.cursor()

# Ejecutar una consulta
cur.execute("""
    SELECT
    c.first_name || ' ' || c.last_name AS customer_name,
    e.first_name || ' ' || e.last_name AS support_rep
FROM Customer c
JOIN Employee e ON c.support_rep_id = e.employee_id;
""")
rows = cur.fetchall()

# Mostrar resultados
for row in rows:
    print(row)



# Cerrar conexiones
cur.close()
conn.close()

print('-------------------------')

results = db.employees.aggregate([
    {"$unwind": "$customers"},
    {
        "$project": {
            "_id": 0,
            "customer_name": "$customers.customer_name",
            "support_rep": {
                "$concat": ["$first_name", " ", "$last_name"]
            }
        }
    }
])

for doc in results:
  print(f"('{doc['customer_name']}', '{doc['support_rep']}')")
# Out:
# ('Luís Gonçalves', 'Jane Peacock')
# ('Leonie Köhler', 'Steve Johnson')
# ('François Tremblay', 'Jane Peacock')
# ('Bjørn Hansen', 'Margaret Park')
# ('František Wichterlová', 'Margaret Park')
# ('Helena Holý', 'Steve Johnson')
# ('Astrid Gruber', 'Steve Johnson')
# ('Daan Peeters', 'Margaret Park')
# ('Kara Nielsen', 'Margaret Park')
# ('Eduardo Martins', 'Margaret Park')
# ('Alexandre Rocha', 'Steve Johnson')
# ('Roberto Almeida', 'Jane Peacock')
# ('Fernanda Ramos', 'Margaret Park')
# ('Mark Philips', 'Steve Johnson')
# ('Jennifer Peterson', 'Jane Peacock')
# ('Frank Harris', 'Margaret Park')
# ('Jack Smith', 'Steve Johnson')
# ('Michelle Brooks', 'Jane Peacock')
# ('Tim Goyer', 'Jane Peacock')
# ('Dan Miller', 'Margaret Park')
# ('Kathy Chase', 'Steve Johnson')
# ('Heather Leacock', 'Margaret Park')
# ('John Gordon', 'Margaret Park')
# ('Frank Ralston', 'Jane Peacock')
# ('Victor Stevens', 'Steve Johnson')
# ('Richard Cunningham', 'Margaret Park')
# ('Patrick Gray', 'Margaret Park')
# ('Julia Barnett', 'Steve Johnson')
# ('Robert Brown', 'Jane Peacock')
# ('Edward Francis', 'Jane Peacock')
# ('Martha Silk', 'Steve Johnson')
# ('Aaron Mitchell', 'Margaret Park')
# ('Ellie Sullivan', 'Jane Peacock')
# ('João Fernandes', 'Margaret Park')
# ('Madalena Sampaio', 'Margaret Park')
# ('Hannah Schneider', 'Steve Johnson')
# ('Fynn Zimmermann', 'Jane Peacock')
# ('Niklas Schröder', 'Jane Peacock')
# ('Camille Bernard', 'Margaret Park')
# ('Dominique Lefebvre', 'Margaret Park')
# ('Marc Dubois', 'Steve Johnson')
# ('Wyatt Girard', 'Jane Peacock')
# ('Isabelle Mercier', 'Jane Peacock')
# ('Terhi Hämäläinen', 'Jane Peacock')
# ('Ladislav Kovács', 'Jane Peacock')
# ("Hugh O'Reilly", 'Jane Peacock')
# ('Lucas Mancini', 'Steve Johnson')
# ('Johannes Van der Berg', 'Steve Johnson')
# ('Stanisław Wójcik', 'Margaret Park')
# ('Enrique Muñoz', 'Steve Johnson')
# ('Joakim Johansson', 'Steve Johnson')
# ('Emma Jones', 'Jane Peacock')
# ('Phil Hughes', 'Jane Peacock')
# ('Steve Murray', 'Steve Johnson')
# ('Mark Taylor', 'Margaret Park')
# ('Diego Gutiérrez', 'Margaret Park')
# ('Luis Rojas', 'Steve Johnson')
# ('Manoj Pareek', 'Jane Peacock')
# ('Puja Srivastava', 'Jane Peacock')
# -------------------------
# ('Luís Gonçalves', 'Jane Peacock')
# ('François Tremblay', 'Jane Peacock')
# ('Roberto Almeida', 'Jane Peacock')
# ('Jennifer Peterson', 'Jane Peacock')
# ('Michelle Brooks', 'Jane Peacock')
# ('Tim Goyer', 'Jane Peacock')
# ('Frank Ralston', 'Jane Peacock')
# ('Robert Brown', 'Jane Peacock')
# ('Edward Francis', 'Jane Peacock')
# ('Ellie Sullivan', 'Jane Peacock')
# ('Fynn Zimmermann', 'Jane Peacock')
# ('Niklas Schröder', 'Jane Peacock')
# ('Wyatt Girard', 'Jane Peacock')
# ('Isabelle Mercier', 'Jane Peacock')
# ('Terhi Hämäläinen', 'Jane Peacock')
# ('Ladislav Kovács', 'Jane Peacock')
# ('Hugh O'Reilly', 'Jane Peacock')
# ('Emma Jones', 'Jane Peacock')
# ('Phil Hughes', 'Jane Peacock')
# ('Manoj Pareek', 'Jane Peacock')
# ('Puja Srivastava', 'Jane Peacock')
# ('Bjørn Hansen', 'Margaret Park')
# ('František Wichterlová', 'Margaret Park')
# ('Daan Peeters', 'Margaret Park')
# ('Kara Nielsen', 'Margaret Park')
# ('Eduardo Martins', 'Margaret Park')
# ('Fernanda Ramos', 'Margaret Park')
# ('Frank Harris', 'Margaret Park')
# ('Dan Miller', 'Margaret Park')
# ('Heather Leacock', 'Margaret Park')
# ('John Gordon', 'Margaret Park')
# ('Richard Cunningham', 'Margaret Park')
# ('Patrick Gray', 'Margaret Park')
# ('Aaron Mitchell', 'Margaret Park')
# ('João Fernandes', 'Margaret Park')
# ('Madalena Sampaio', 'Margaret Park')
# ('Camille Bernard', 'Margaret Park')
# ('Dominique Lefebvre', 'Margaret Park')
# ('Stanisław Wójcik', 'Margaret Park')
# ('Mark Taylor', 'Margaret Park')
# ('Diego Gutiérrez', 'Margaret Park')
# ('Leonie Köhler', 'Steve Johnson')
# ('Helena Holý', 'Steve Johnson')
# ('Astrid Gruber', 'Steve Johnson')
# ('Alexandre Rocha', 'Steve Johnson')
# ('Mark Philips', 'Steve Johnson')
# ('Jack Smith', 'Steve Johnson')
# ('Kathy Chase', 'Steve Johnson')
# ('Victor Stevens', 'Steve Johnson')
# ('Julia Barnett', 'Steve Johnson')
# ('Martha Silk', 'Steve Johnson')
# ('Hannah Schneider', 'Steve Johnson')
# ('Marc Dubois', 'Steve Johnson')
# ('Lucas Mancini', 'Steve Johnson')
# ('Johannes Van der Berg', 'Steve Johnson')
# ('Enrique Muñoz', 'Steve Johnson')
# ('Joakim Johansson', 'Steve Johnson')
# ('Steve Murray', 'Steve Johnson')
# ('Luis Rojas', 'Steve Johnson')

# %%
import psycopg2
# # Mostrar que empleado roporta a quien
# Conexión usando variables de entorno
conn = get_postgres_connection()
cur = conn.cursor()

# Ejecutar una consulta
cur.execute("""
    SELECT
    e.first_name || ' ' || e.last_name AS employee_name,
    m.first_name || ' ' || m.last_name AS manager_name
FROM Employee e
JOIN Employee m ON e.reports_to = m.employee_id;
""")
rows = cur.fetchall()

# Mostrar resultados
for row in rows:
    print(row)



# Cerrar conexiones
cur.close()
conn.close()

print("------------------------------")

results = db.employees.find({}, {'first_name': 1, 'last_name': 1, 'reports_to': 1, '_id': 0})
for doc in results:
  print(f"Empleado: {doc['first_name']} {doc['last_name']} reporta a {doc['reports_to']}")
# Out:
# ('Nancy Edwards', 'Andrew Adams')
# ('Jane Peacock', 'Nancy Edwards')
# ('Margaret Park', 'Nancy Edwards')
# ('Steve Johnson', 'Nancy Edwards')
# ('Michael Mitchell', 'Andrew Adams')
# ('Robert King', 'Michael Mitchell')
# ('Laura Callahan', 'Michael Mitchell')
# ------------------------------
# Empleado: Andrew Adams reporta a None
# Empleado: Nancy Edwards reporta a Andrew Adams
# Empleado: Jane Peacock reporta a Nancy Edwards
# Empleado: Margaret Park reporta a Nancy Edwards
# Empleado: Steve Johnson reporta a Nancy Edwards
# Empleado: Michael Mitchell reporta a Andrew Adams
# Empleado: Robert King reporta a Michael Mitchell
# Empleado: Laura Callahan reporta a Michael Mitchell

# %%
import psycopg2
# Listado detallado de compras hechas por un cliente dado
# Conexión usando variables de entorno
conn = get_postgres_connection()
cur = conn.cursor()

# Ejecutar una consulta
cur.execute("""
    SELECT
    i.invoice_id,
    TO_CHAR(i.invoice_date, 'yyyy/mm/dd') AS invoice_date,
    c.first_name || ' ' || c.last_name AS customer_name,
    t.name AS track_name,
    il.quantity,
    il.unit_price,
    (il.quantity * il.unit_price) AS line_total
FROM invoice i
JOIN customer c ON i.customer_id = c.customer_id
JOIN invoice_line il ON i.invoice_id = il.invoice_id
JOIN track t ON il.track_id = t.track_id
where c.customer_id = 10
ORDER BY i.invoice_date DESC, i.invoice_id;
""")
rows = cur.fetchall()

# Mostrar resultados
for row in rows:
    print(row)



# Cerrar conexiones
cur.close()
conn.close()

print("------------------------------")

results = db.customers.aggregate([
    {"$match": {"customer_id": 10}},
    {"$unwind": "$invoices"},
    {"$unwind": "$invoices.invoice_lines"},
    {
        "$lookup": {
            "from": "tracks",
            "localField": "invoices.invoice_lines.track_id",
            "foreignField": "track_id",
            "as": "track_info"
        }
    },
    {"$unwind": "$track_info"},
    {
        "$project": {
            "_id": 0,
            "invoice_id": "$invoices.invoice_id",
            "invoice_date": {
                "$dateToString": {
                    "format": "%Y/%m/%d",
                    "date": "$invoices.invoice_date"
                }
            },
            "customer_name": {
                "$concat": ["$first_name", " ", "$last_name"]
            },
            "track_name": "$track_info.name",
            "quantity": "$invoices.invoice_lines.quantity",
            "unit_price": "$invoices.invoice_lines.unit_price",
            "line_total": {
                "$multiply": [
                    "$invoices.invoice_lines.quantity",
                    "$invoices.invoice_lines.unit_price"
                ]
            }
        }
    },
    {
        "$sort": {
            "invoice_date": -1,
            "invoice_id": 1
        }
    }
])

for doc in results:
    print(f"({doc['invoice_id']}, '{doc['invoice_date']}', '{doc['customer_name']}', '{doc['track_name']}', {doc['quantity']}, Decimal('{doc['unit_price']}'), Decimal('{doc['line_total']}'))")
# Out:
# (383, '2025/08/12', 'Eduardo Martins', 'Pick Myself Up', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Dissident', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Most High', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Any Colour You Like', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', "Don't Look Back", 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Oceans', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', '1/2 Full', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Cropduster', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Big Wave', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Black', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Untitled', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Sanctuary', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Plot 180', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Your Blue Room', 1, Decimal('0.99'), Decimal('0.99'))
# (372, '2025/07/02', 'Eduardo Martins', 'Down Under', 1, Decimal('0.99'), Decimal('0.99'))
# (372, '2025/07/02', 'Eduardo Martins', 'Praise', 1, Decimal('0.99'), Decimal('0.99'))
# (251, '2024/01/09', 'Eduardo Martins', 'Aces High', 1, Decimal('0.99'), Decimal('0.99'))
# (199, '2023/05/21', 'Eduardo Martins', 'Red Light', 1, Decimal('0.99'), Decimal('0.99'))
# (199, '2023/05/21', 'Eduardo Martins', 'Bad', 1, Decimal('0.99'), Decimal('0.99'))
# (199, '2023/05/21', 'Eduardo Martins', 'Sweetest Thing', 1, Decimal('0.99'), Decimal('0.99'))
# (199, '2023/05/21', 'Eduardo Martins', 'All I Want Is You', 1, Decimal('0.99'), Decimal('0.99'))
# (199, '2023/05/21', 'Eduardo Martins', 'Like A Song...', 1, Decimal('0.99'), Decimal('0.99'))
# (199, '2023/05/21', 'Eduardo Martins', 'Babyface', 1, Decimal('0.99'), Decimal('0.99'))
# (177, '2023/02/16', 'Eduardo Martins', 'Binky The Doormat', 1, Decimal('0.99'), Decimal('0.99'))
# (177, '2023/02/16', 'Eduardo Martins', 'Bittersweet Me', 1, Decimal('0.99'), Decimal('0.99'))
# (177, '2023/02/16', 'Eduardo Martins', 'Electrolite', 1, Decimal('0.99'), Decimal('0.99'))
# (177, '2023/02/16', 'Eduardo Martins', 'So Fast, So Numb', 1, Decimal('0.99'), Decimal('0.99'))
# (154, '2022/11/14', 'Eduardo Martins', 'No Quarter', 1, Decimal('0.99'), Decimal('0.99'))
# (154, '2022/11/14', 'Eduardo Martins', "D'Yer Mak'er", 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Child In Time', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Drifter', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Admirável Gado Novo', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Mis Penas Lloraba Yo (Ao Vivo) Soy Gitano (Tangos)', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Vavoom : Ted The Mechanic', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', "Maybe I'm A Leo", 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'The Unwritten Law', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Knocking At Your Back Door', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'No No No', 1, Decimal('0.99'), Decimal('0.99'))
# ------------------------------
# (383, '2025/08/12', 'Eduardo Martins', 'Any Colour You Like', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Most High', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Your Blue Room', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Plot 180', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Sanctuary', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Untitled', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Black', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Big Wave', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Cropduster', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', '1/2 Full', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Oceans', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Dissident', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Don't Look Back', 1, Decimal('0.99'), Decimal('0.99'))
# (383, '2025/08/12', 'Eduardo Martins', 'Pick Myself Up', 1, Decimal('0.99'), Decimal('0.99'))
# (372, '2025/07/02', 'Eduardo Martins', 'Down Under', 1, Decimal('0.99'), Decimal('0.99'))
# (372, '2025/07/02', 'Eduardo Martins', 'Praise', 1, Decimal('0.99'), Decimal('0.99'))
# (251, '2024/01/09', 'Eduardo Martins', 'Aces High', 1, Decimal('0.99'), Decimal('0.99'))
# (199, '2023/05/21', 'Eduardo Martins', 'Red Light', 1, Decimal('0.99'), Decimal('0.99'))
# (199, '2023/05/21', 'Eduardo Martins', 'Babyface', 1, Decimal('0.99'), Decimal('0.99'))
# (199, '2023/05/21', 'Eduardo Martins', 'Like A Song...', 1, Decimal('0.99'), Decimal('0.99'))
# (199, '2023/05/21', 'Eduardo Martins', 'All I Want Is You', 1, Decimal('0.99'), Decimal('0.99'))
# (199, '2023/05/21', 'Eduardo Martins', 'Sweetest Thing', 1, Decimal('0.99'), Decimal('0.99'))
# (199, '2023/05/21', 'Eduardo Martins', 'Bad', 1, Decimal('0.99'), Decimal('0.99'))
# (177, '2023/02/16', 'Eduardo Martins', 'Electrolite', 1, Decimal('0.99'), Decimal('0.99'))
# (177, '2023/02/16', 'Eduardo Martins', 'So Fast, So Numb', 1, Decimal('0.99'), Decimal('0.99'))
# (177, '2023/02/16', 'Eduardo Martins', 'Binky The Doormat', 1, Decimal('0.99'), Decimal('0.99'))
# (177, '2023/02/16', 'Eduardo Martins', 'Bittersweet Me', 1, Decimal('0.99'), Decimal('0.99'))
# (154, '2022/11/14', 'Eduardo Martins', 'No Quarter', 1, Decimal('0.99'), Decimal('0.99'))
# (154, '2022/11/14', 'Eduardo Martins', 'D'Yer Mak'er', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Admirável Gado Novo', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Vavoom : Ted The Mechanic', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Maybe I'm A Leo', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'The Unwritten Law', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Knocking At Your Back Door', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'No No No', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Child In Time', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Drifter', 1, Decimal('0.99'), Decimal('0.99'))
# (25, '2021/04/09', 'Eduardo Martins', 'Mis Penas Lloraba Yo (Ao Vivo) Soy Gitano (Tangos)', 1, Decimal('0.99'), Decimal('0.99'))

# %%
cols = ["albums","tracks","playlists","customers","employees"];
for c in cols:
  colecciones = db.list_collection_names()
  if c not in colecciones:
      db.create_collection(c)
      print("✔ Colección creada:", c)

# %%
# Crear indices
# Albums
db.albums.create_index({ "album_id": 1 }, unique=True)
db.albums.create_index({ "artist_id": 1 })
db.albums.create_index({ "tracks.track_id": 1 })

# Tracks
db.tracks.create_index({ "track_id": 1 }, unique=True)
db.tracks.create_index([("genre", 1), ("sales.total_quantity", -1)])
db.tracks.create_index({ "artist_id": 1 })

# Playlists
db.playlists.create_index({ "playlist_id": 1 }, unique=True)
db.playlists.create_index({ "tracks.track_id": 1 })

# Customers
db.customers.create_index({ "customer_id": 1 }, unique=True)
db.customers.create_index({ "total_spent": -1 })
db.customers.create_index({ "support_rep.employee_id": 1 })
db.customers.create_index({ "invoices.invoice_id": 1 })
db.customers.create_index({ "invoices.invoice_date": 1 })
db.customers.create_index({ "invoices.billing_country": 1 })

# Employees
db.employees.create_index({ "employee_id": 1 }, unique=True)
db.employees.create_index({ "customers.customer_id": 1 })
# Out:
# 'customers.customer_id_1'

# %%
def migrate(cur, db):
    # Limpia colecciones existentes (opcional)
    for coll in ['albums', 'tracks', 'playlists', 'customers', 'employees']:
        db[coll].delete_many({})

    # 1) Albums + tracks embebidos
    cur.execute("SELECT * FROM album;")
    for alb in cur.fetchall():
        cur.execute("""
            SELECT t.track_id,
                   t.name,
                   t.media_type_id,
                   mt.name AS media_type_name,
                   t.genre_id,
                   g.name AS genre_name,
                   t.composer,
                   t.milliseconds,
                   t.bytes,
                   t.unit_price
            FROM track t
            JOIN media_type mt ON t.media_type_id = mt.media_type_id
            JOIN genre g ON t.genre_id = g.genre_id
            WHERE t.album_id = %s;
        """, (alb['album_id'],))
        tracks = cur.fetchall()

        alb_doc = {
            'album_id':     alb['album_id'],
            'artist_id':    alb['artist_id'],
            'title':        alb['title'],
            'tracks': [{
                'track_id':    tr['track_id'],
                'media': {
                    'media_type_id': tr['media_type_id'],
                    'name':          tr['media_type_name']
                },
                'genre': {
                    'genre_id': tr['genre_id'],
                    'name':     tr['genre_name']
                },
                'name':        tr['name'],
                'composer':    tr['composer'],
                'milliseconds':tr['milliseconds'],
                'bytes':       tr['bytes'],
                'unit_price':  float(tr['unit_price'])
            } for tr in tracks]
        }
        db.albums.insert_one(alb_doc)

    # 2) Tracks sueltos + stats de ventas
    cur.execute("SELECT * FROM track;")
    for tr in cur.fetchall():
        cur.execute("SELECT title, artist_id FROM album WHERE album_id = %s;", (tr['album_id'],))
        alb_info = cur.fetchone()
        cur.execute("SELECT name FROM artist WHERE artist_id = %s;", (alb_info['artist_id'],))
        artist_info = cur.fetchone()
        cur.execute("""
            SELECT SUM(quantity)       AS total_quantity,
                   SUM(quantity*unit_price) AS total_revenue
            FROM invoice_line
            WHERE track_id = %s;
        """, (tr['track_id'],))
        sales = cur.fetchone() or {}
        total_revenue = float(sales.get('total_revenue', 0.0)) if sales.get('total_revenue') else 0.0
        tr_doc = {
            'track_id':     tr['track_id'],
            'name':         tr['name'],
            'album_id':     tr['album_id'],
            'album_name':   alb_info['title'],
            'artist_id':    alb_info['artist_id'],
            'artist_name':  artist_info['name'],
            'genre_id':     tr['genre_id'],
            'composer':     tr['composer'],
            'milliseconds': tr['milliseconds'],
            'bytes':        tr['bytes'],
            'unit_price':   float(tr['unit_price']),
            'sales': {
                'total_quantity': sales.get('total_quantity', 0),
                'total_revenue':  total_revenue
            }
        }
        db.tracks.insert_one(tr_doc)

    # 3) Playlists
    cur.execute("SELECT * FROM playlist;")
    for pl in cur.fetchall():
        cur.execute("""
            SELECT pt.track_id,
                   t.name AS track_name,
                   t.album_id
            FROM playlist_track pt
            JOIN track t ON pt.track_id = t.track_id
            WHERE pt.playlist_id = %s;
        """, (pl['playlist_id'],))
        pts = cur.fetchall()

        pl_doc = {
            'playlist_id': pl['playlist_id'],
            'name':        pl['name'],
            'tracks': [{
                'track_id':  pt['track_id'],
                'track_name':pt['track_name'],
                'album_id':  pt['album_id']
            } for pt in pts]
        }
        db.playlists.insert_one(pl_doc)

    # 4) Customers + invoices embebidas
    cur.execute("SELECT * FROM customer;")
    for cus in cur.fetchall():
        cur.execute("""
            SELECT employee_id,
                   first_name || ' ' || last_name AS employee_name
            FROM employee
            WHERE employee_id = %s;
        """, (cus['support_rep_id'],))
        rep = cur.fetchone() or {}

        cur.execute("SELECT * FROM invoice WHERE customer_id = %s;", (cus['customer_id'],))
        inv_docs = []
        total_spent = 0.0
        for inv in cur.fetchall():
            cur.execute("SELECT track_id, unit_price, quantity FROM invoice_line WHERE invoice_id = %s;", (inv['invoice_id'],))
            lines = cur.fetchall()
            inv_total = sum(float(line['unit_price']) * line['quantity'] for line in lines)
            total_spent += inv_total

            inv_docs.append({
                'invoice_id':      inv['invoice_id'],
                'invoice_lines':  [{'track_id': l['track_id'], 'unit_price': float(l['unit_price']), 'quantity': l['quantity']} for l in lines],
                'total':           inv_total,
                'invoice_date':    inv['invoice_date'],
                'billing_address': inv['billing_address'],
                'billing_city':    inv['billing_city'],
                'billing_state':   inv['billing_state'],
                'billing_country': inv['billing_country'],
                'billing_postal_code': inv['billing_postal_code']
            })

        cus_doc = {
            'customer_id': cus['customer_id'],
            'first_name':  cus['first_name'],
            'last_name':   cus['last_name'],
            'company':     cus['company'],
            'address':     cus['address'],
            'city':        cus['city'],
            'state':       cus['state'],
            'postal_code': cus['postal_code'],
            'fax':         cus['fax'],
            'email':       cus['email'],
            'support_rep': rep,
            'invoices':    inv_docs,
            'total_spent': total_spent
        }
        db.customers.insert_one(cus_doc)

    # 5) Employees + clientes embebidos
    cur.execute("SELECT * FROM employee;")
    for emp in cur.fetchall():
        cur.execute("""
            SELECT customer_id,
                   first_name || ' ' || last_name AS customer_name
            FROM customer
            WHERE support_rep_id = %s;
        """, (emp['employee_id'],))
        custs = cur.fetchall()

        cur.execute("""
          SELECT m.first_name || ' ' || m.last_name AS manager_name
          FROM Employee e
          JOIN Employee m ON e.reports_to = m.employee_id
          WHERE e.employee_id = %s;
        """, (emp['employee_id'],))
        manager = cur.fetchone()

        emp_doc = {
            'employee_id':   emp['employee_id'],
            'first_name':    emp['first_name'],
            'last_name':     emp['last_name'],
            'reports_to':    manager['manager_name'] if manager else None,
            'customer_count': len(custs),
            'customers':    [{'customer_id': c['customer_id'], 'customer_name': c['customer_name']} for c in custs]
        }
        db.employees.insert_one(emp_doc)

    print("✅ Migración completada.")

import psycopg2
import psycopg2.extras


# Conexión usando variables de entorno
conn = get_postgres_connection()

cur = conn.cursor(cursor_factory=psycopg2.extras.RealDictCursor)

migrate(cur, db)
cur.close()
conn.close()
# Out:
# ✅ Migración completada.
